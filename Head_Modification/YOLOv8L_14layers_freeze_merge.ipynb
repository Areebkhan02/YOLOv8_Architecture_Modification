# %%
# %pwd
# %cd ..
# %cd ultralytics
# Out:
# /home/areebadnan/Areeb_code/work/Atheritia
# /home/areebadnan/Areeb_code/work/Atheritia/ultralytics
# /home/areebadnan/Areeb_Python_Environments/yolo_env1/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from ultralytics import YOLO
import torch
import copy


# Initialize pretrained model
#model = YOLO('yolov8n.pt')

model_yaml = YOLO("/home/areebadnan/Areeb_code/work/Atheritia/ultralytics/ultralytics/cfg/models/v8/yolov8l-test.yaml", task= "detect")

# Keep a copy of old state dict for sanity check
old_dict = copy.deepcopy(model_yaml.state_dict())

# We should freeze all but the last layer
model_yaml.state_dict().keys()
# Out:
# odict_keys(['model.model.0.conv.weight', 'model.model.0.bn.weight', 'model.model.0.bn.bias', 'model.model.0.bn.running_mean', 'model.model.0.bn.running_var', 'model.model.0.bn.num_batches_tracked', 'model.model.1.conv.weight', 'model.model.1.bn.weight', 'model.model.1.bn.bias', 'model.model.1.bn.running_mean', 'model.model.1.bn.running_var', 'model.model.1.bn.num_batches_tracked', 'model.model.2.cv1.conv.weight', 'model.model.2.cv1.bn.weight', 'model.model.2.cv1.bn.bias', 'model.model.2.cv1.bn.running_mean', 'model.model.2.cv1.bn.running_var', 'model.model.2.cv1.bn.num_batches_tracked', 'model.model.2.cv2.conv.weight', 'model.model.2.cv2.bn.weight', 'model.model.2.cv2.bn.bias', 'model.model.2.cv2.bn.running_mean', 'model.model.2.cv2.bn.running_var', 'model.model.2.cv2.bn.num_batches_tracked', 'model.model.2.m.0.cv1.conv.weight', 'model.model.2.m.0.cv1.bn.weight', 'model.model.2.m.0.cv1.bn.bias', 'model.model.2.m.0.cv1.bn.running_mean', 'model.model.2.m.0.cv1.bn.running_var', 'model.model.2.m.0.cv1.bn.num_batches_tracked', 'model.model.2.m.0.cv2.conv.weight', 'model.model.2.m.0.cv2.bn.weight', 'model.model.2.m.0.cv2.bn.bias', 'model.model.2.m.0.cv2.bn.running_mean', 'model.model.2.m.0.cv2.bn.running_var', 'model.model.2.m.0.cv2.bn.num_batches_tracked', 'model.model.2.m.1.cv1.conv.weight', 'model.model.2.m.1.cv1.bn.weight', 'model.model.2.m.1.cv1.bn.bias', 'model.model.2.m.1.cv1.bn.running_mean', 'model.model.2.m.1.cv1.bn.running_var', 'model.model.2.m.1.cv1.bn.num_batches_tracked', 'model.model.2.m.1.cv2.conv.weight', 'model.model.2.m.1.cv2.bn.weight', 'model.model.2.m.1.cv2.bn.bias', 'model.model.2.m.1.cv2.bn.running_mean', 'model.model.2.m.1.cv2.bn.running_var', 'model.model.2.m.1.cv2.bn.num_batches_tracked', 'model.model.2.m.2.cv1.conv.weight', 'model.model.2.m.2.cv1.bn.weight', 'model.model.2.m.2.cv1.bn.bias', 'model.model.2.m.2.cv1.bn.running_mean', 'model.model.2.m.2.cv1.bn.running_var', 'model.model.2.m.2.cv1.bn.num_batches_tracked', 'model.model.2.m.2.cv2.conv.weight', 'model.model.2.m.2.cv2.bn.weight', 'model.model.2.m.2.cv2.bn.bias', 'model.model.2.m.2.cv2.bn.running_mean', 'model.model.2.m.2.cv2.bn.running_var', 'model.model.2.m.2.cv2.bn.num_batches_tracked', 'model.model.3.conv.weight', 'model.model.3.bn.weight', 'model.model.3.bn.bias', 'model.model.3.bn.running_mean', 'model.model.3.bn.running_var', 'model.model.3.bn.num_batches_tracked', 'model.model.4.cv1.conv.weight', 'model.model.4.cv1.bn.weight', 'model.model.4.cv1.bn.bias', 'model.model.4.cv1.bn.running_mean', 'model.model.4.cv1.bn.running_var', 'model.model.4.cv1.bn.num_batches_tracked', 'model.model.4.cv2.conv.weight', 'model.model.4.cv2.bn.weight', 'model.model.4.cv2.bn.bias', 'model.model.4.cv2.bn.running_mean', 'model.model.4.cv2.bn.running_var', 'model.model.4.cv2.bn.num_batches_tracked', 'model.model.4.m.0.cv1.conv.weight', 'model.model.4.m.0.cv1.bn.weight', 'model.model.4.m.0.cv1.bn.bias', 'model.model.4.m.0.cv1.bn.running_mean', 'model.model.4.m.0.cv1.bn.running_var', 'model.model.4.m.0.cv1.bn.num_batches_tracked', 'model.model.4.m.0.cv2.conv.weight', 'model.model.4.m.0.cv2.bn.weight', 'model.model.4.m.0.cv2.bn.bias', 'model.model.4.m.0.cv2.bn.running_mean', 'model.model.4.m.0.cv2.bn.running_var', 'model.model.4.m.0.cv2.bn.num_batches_tracked', 'model.model.4.m.1.cv1.conv.weight', 'model.model.4.m.1.cv1.bn.weight', 'model.model.4.m.1.cv1.bn.bias', 'model.model.4.m.1.cv1.bn.running_mean', 'model.model.4.m.1.cv1.bn.running_var', 'model.model.4.m.1.cv1.bn.num_batches_tracked', 'model.model.4.m.1.cv2.conv.weight', 'model.model.4.m.1.cv2.bn.weight', 'model.model.4.m.1.cv2.bn.bias', 'model.model.4.m.1.cv2.bn.running_mean', 'model.model.4.m.1.cv2.bn.running_var', 'model.model.4.m.1.cv2.bn.num_batches_tracked', 'model.model.4.m.2.cv1.conv.weight', 'model.model.4.m.2.cv1.bn.weight', 'model.model.4.m.2.cv1.bn.bias', 'model.model.4.m.2.cv1.bn.running_mean', 'model.model.4.m.2.cv1.bn.running_var', 'model.model.4.m.2.cv1.bn.num_batches_tracked', 'model.model.4.m ...

# %%
def compare_dicts(state_dict1, state_dict2):
    # Compare the keys
    keys1 = set(state_dict1.keys())
    keys2 = set(state_dict2.keys())

    if keys1 != keys2:
        print("Models have different parameter names.")
        return False

    # Compare the values (weights)
    for key in keys1:
        if not torch.equal(state_dict1[key], state_dict2[key]):
            print(f"Weights for parameter '{key}' are different.")
            if "bn" in key and "22" not in key:
              state_dict1[key] = state_dict2[key]

# %%
model_2 = YOLO("/home/areebadnan/Areeb_code/work/Atheritia/ultralytics/17logos_head_17logosbase_L/train/weights/best.pt") # 22 layers
model_1 = YOLO("/home/areebadnan/Areeb_code/work/Atheritia/47_(10)_logos_head_17logosbase_L_3/train/weights/best.pt") # 14 layers

# %%
model_2
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-2): 3 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-5): 6 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-5): 6 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-2): 3 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-2): 3 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(640, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-2): 3 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-2): 3 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-2): 3 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=False)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(256, 17, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(256, 17, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
total_params  = sum(p.numel() for p in model_2.parameters() if p.requires_grad)
print (total_params)
# Out:
# 0

# %%
for name, param in model_2.named_parameters():
    #if param.requires_grad:
        print (name,param.requires_grad)
# Out:
# model.model.0.conv.weight False
# model.model.0.bn.weight False
# model.model.0.bn.bias False
# model.model.1.conv.weight False
# model.model.1.bn.weight False
# model.model.1.bn.bias False
# model.model.2.cv1.conv.weight False
# model.model.2.cv1.bn.weight False
# model.model.2.cv1.bn.bias False
# model.model.2.cv2.conv.weight False
# model.model.2.cv2.bn.weight False
# model.model.2.cv2.bn.bias False
# model.model.2.m.0.cv1.conv.weight False
# model.model.2.m.0.cv1.bn.weight False
# model.model.2.m.0.cv1.bn.bias False
# model.model.2.m.0.cv2.conv.weight False
# model.model.2.m.0.cv2.bn.weight False
# model.model.2.m.0.cv2.bn.bias False
# model.model.2.m.1.cv1.conv.weight False
# model.model.2.m.1.cv1.bn.weight False
# model.model.2.m.1.cv1.bn.bias False
# model.model.2.m.1.cv2.conv.weight False
# model.model.2.m.1.cv2.bn.weight False
# model.model.2.m.1.cv2.bn.bias False
# model.model.2.m.2.cv1.conv.weight False
# model.model.2.m.2.cv1.bn.weight False
# model.model.2.m.2.cv1.bn.bias False
# model.model.2.m.2.cv2.conv.weight False
# model.model.2.m.2.cv2.bn.weight False
# model.model.2.m.2.cv2.bn.bias False
# model.model.3.conv.weight False
# model.model.3.bn.weight False
# model.model.3.bn.bias False
# model.model.4.cv1.conv.weight False
# model.model.4.cv1.bn.weight False
# model.model.4.cv1.bn.bias False
# model.model.4.cv2.conv.weight False
# model.model.4.cv2.bn.weight False
# model.model.4.cv2.bn.bias False
# model.model.4.m.0.cv1.conv.weight False
# model.model.4.m.0.cv1.bn.weight False
# model.model.4.m.0.cv1.bn.bias False
# model.model.4.m.0.cv2.conv.weight False
# model.model.4.m.0.cv2.bn.weight False
# model.model.4.m.0.cv2.bn.bias False
# model.model.4.m.1.cv1.conv.weight False
# model.model.4.m.1.cv1.bn.weight False
# model.model.4.m.1.cv1.bn.bias False
# model.model.4.m.1.cv2.conv.weight False
# model.model.4.m.1.cv2.bn.weight False
# model.model.4.m.1.cv2.bn.bias False
# model.model.4.m.2.cv1.conv.weight False
# model.model.4.m.2.cv1.bn.weight False
# model.model.4.m.2.cv1.bn.bias False
# model.model.4.m.2.cv2.conv.weight False
# model.model.4.m.2.cv2.bn.weight False
# model.model.4.m.2.cv2.bn.bias False
# model.model.4.m.3.cv1.conv.weight False
# model.model.4.m.3.cv1.bn.weight False
# model.model.4.m.3.cv1.bn.bias False
# model.model.4.m.3.cv2.conv.weight False
# model.model.4.m.3.cv2.bn.weight False
# model.model.4.m.3.cv2.bn.bias False
# model.model.4.m.4.cv1.conv.weight False
# model.model.4.m.4.cv1.bn.weight False
# model.model.4.m.4.cv1.bn.bias False
# model.model.4.m.4.cv2.conv.weight False
# model.model.4.m.4.cv2.bn.weight False
# model.model.4.m.4.cv2.bn.bias False
# model.model.4.m.5.cv1.conv.weight False
# model.model.4.m.5.cv1.bn.weight False
# model.model.4.m.5.cv1.bn.bias False
# model.model.4.m.5.cv2.conv.weight False
# model.model.4.m.5.cv2.bn.weight False
# model.model.4.m.5.cv2.bn.bias False
# model.model.5.conv.weight False
# model.model.5.bn.weight False
# model.model.5.bn.bias False
# model.model.6.cv1.conv.weight False
# model.model.6.cv1.bn.weight False
# model.model.6.cv1.bn.bias False
# model.model.6.cv2.conv.weight False
# model.model.6.cv2.bn.weight False
# model.model.6.cv2.bn.bias False
# model.model.6.m.0.cv1.conv.weight False
# model.model.6.m.0.cv1.bn.weight False
# model.model.6.m.0.cv1.bn.bias False
# model.model.6.m.0.cv2.conv.weight False
# model.model.6.m.0.cv2.bn.weight False
# model.model.6.m.0.cv2.bn.bias False
# model.model.6.m.1.cv1.conv.weight False
# model.model.6.m.1.cv1.bn.weight False
# model.model.6.m.1.cv1.bn.bias False
# model.model.6.m.1.cv2.conv.weight False
# model.model.6.m.1.cv2.bn.weight False
# model.model.6.m.1.cv2.bn.bias False
# model.model.6.m.2.cv1.conv.weight False
# model.model.6.m.2.cv1.bn.weight False
# model.model.6.m.2.cv1.bn.bias False
# model.model.6.m.2.cv2.conv.weight False
# model.model.6.m.2.cv2.bn.weight False
# model.model.6.m.2.cv2.bn.bias False
# model.model.6.m.3.cv1.conv.weight False
# model.model.6.m.3.cv1.bn.weight False
# model.model.6.m.3.cv1.bn.bias False
# model.model.6.m.3.cv2.conv.weight False
# model.model.6.m.3.cv2.bn.weight False
# model.model.6.m.3.cv2.bn.bias False
# model.model.6.m.4.cv1.conv.weight False
# model.model.6.m.4.cv1.bn.weight False
# model.model.6.m.4.cv1.bn.bias False
# model.model.6.m.4.cv2.conv.weight False
# model.model.6.m.4.cv2.bn.weight False
# model.model.6.m.4.cv2.bn.bias False
# model.model.6.m.5.cv1.conv.weight False
# model.model.6.m.5.cv1.bn.weight False
# model.model.6.m.5.cv1.bn.bias False
# model.model.6.m.5.cv2.conv.weight False
# model.model.6.m.5.cv2.bn.weight False
# model.model.6.m.5.cv2.bn.bias False
# model.model.7.conv.weight False
# model.model.7.bn.weight False
# model.model.7.bn.bias False
# model.model.8.cv1.conv.weight False
# model.model.8.cv1.bn.weight False
# model.model.8.cv1.bn.bias False
# model.model.8.cv2.conv.weight False
# model.model.8.cv2.bn.weight False
# model.model.8.cv2.bn.bias False
# model.model.8.m.0.cv1.conv.weight False
# model.model.8.m.0.cv1.bn.weight False
# model.model.8.m.0.cv1.bn.bias False
# model.model.8.m.0.cv2.conv.weight False
# model.model.8.m.0.cv2.bn.weight False
# model.model.8.m.0.cv2.bn.bias False
# model.model.8.m.1.cv1.conv.weight False
# model.model.8.m.1.cv1.bn.weight False
# model.model.8.m.1.cv1.bn.bias False
# model.model.8.m.1.cv2.conv.weight False
# model.model.8.m.1.cv2.bn.weight False
# model.model.8.m.1.cv2.bn.bias False
# model.model.8.m.2.cv1.conv.weight False
# model.model.8.m.2.cv1.bn.weight False
# model.model.8.m.2.cv1.bn.bias False
# model.model.8.m.2.cv2.conv.weight False
# model.model.8.m.2.cv2.bn.weight False
# model.model.8.m.2.cv2.bn.bias False
# model.model.9.cv1.conv.weight False
# model.model.9.cv1.bn.weight False
# model.model.9.cv1.bn.bias False
# model.model.9.cv2.conv.weight False
# model.model.9.cv2.bn.weight False
# model.model.9.cv2.bn.bias False
# model.model.12.cv1.conv.weight False
# model.model.12.cv1.bn.weight False
# model.model.12.cv1.bn.bias False
# model.model.12.cv2.conv.weight False
# model.model.12.cv2.bn.weight False
# model.model.12.cv2.bn.bias False
# model.model.12.m.0.cv1.conv.weight False
# model.model.12.m.0.cv1.bn.weight False
# model.model.12.m.0.cv1.bn.bias False
# model.model.12.m.0.cv2.conv.weight False
# model.model.12.m.0.cv2.bn.weight False
# model.model.12.m.0.cv2.bn.bias False
# model.model.12.m.1.cv1.conv.weight False
# model.model.12.m.1.cv1.bn.weight False
# model.model.12.m.1.cv1.bn.bias False
# model.model.12.m.1.cv2.conv.weight False
# model.model.12.m.1.cv2.bn.weight False
# model.model.12.m.1.cv2.bn.bias False
# model.model.12.m.2.cv1.conv.weight False
# model.model.12.m.2.cv1.bn.weight False
# model.model.12.m.2.cv1.bn.bias False
# model.model.12.m.2.cv2.conv.weight False
# model.model.12.m.2.cv2.bn.weight False
# model.model.12.m.2.cv2.bn.bias False
# model.model.15.cv1.conv.weight False
# model.model.15.cv1.bn.weight False
# model.model.15.cv1.bn.bias False
# model.model.15.cv2.conv.weight False
# model.model.15.cv2.bn.weight False
# model.model.15.cv2.bn.bias False
# model.model.15.m.0.cv1.conv.weight False
# model.model.15.m.0.cv1.bn.weight False
# model.model.15.m.0.cv1.bn.bias False
# model.model.15.m.0.cv2.conv.weight False
# model.model.15.m.0.cv2.bn.weight False
# model.model.15.m.0.cv2.bn.bias False
# model.model.15.m.1.cv1.conv.weight False
# model.model.15.m.1.cv1.bn.weight False
# model.model.15.m.1.cv1.bn.bias False
# model.model.15.m.1.cv2.conv.weight False
# model.model.15.m.1.cv2.bn.weight False
# model.model.15.m.1.cv2.bn.bias False
# model.model.15.m.2.cv1.conv.weight False
# model.model.15.m.2.cv1.bn.weight False
# model.model.15.m.2.cv1.bn.bias False
# model.model.15.m.2.cv2.conv.weight False
# model.model.15.m.2.cv2.bn.weight False
# model.model.15.m.2.cv2.bn.bias False
# model.model.16.conv.weight False
# model.model.16.bn.weight False
# model.model.16.bn.bias False
# model.model.18.cv1.conv.weight False
# model.model.18.cv1.bn.weight False
# model.model.18.cv1.bn.bias False
# model.model.18.cv2.conv.weight False
# model.model.18.cv2.bn.weight False
# model.model.18.cv2.bn.bias False
# model.model.18.m.0.cv1.conv.weight False
# model.model.18.m.0.cv1.bn.weight False
# model.model.18.m.0.cv1.bn.bias False
# model.model.18.m.0.cv2.conv.weight False
# model.model.18.m.0.cv2.bn.weight False
# model.model.18.m.0.cv2.bn.bias False
# model.model.18.m.1.cv1.conv.weight False
# model.model.18.m.1.cv1.bn.weight False
# model.model.18.m.1.cv1.bn.bias False
# model.model.18.m.1.cv2.conv.weight False
# model.model.18.m.1.cv2.bn.weight False
# model.model.18.m.1.cv2.bn.bias False
# model.model.18.m.2.cv1.conv.weight False
# model.model.18.m.2.cv1.bn.weight False
# model.model.18.m.2.cv1.bn.bias False
# model.model.18.m.2.cv2.conv.weight False
# model.model.18.m.2.cv2.bn.weight False
# model.model.18.m.2.cv2.bn.bias False
# model.model.19.conv.weight False
# model.model.19.bn.weight False
# model.model.19.bn.bias False
# model.model.21.cv1.conv.weight False
# model.model.21.cv1.bn.weight False
# model.model.21.cv1.bn.bias False
# model.model.21.cv2.conv.weight False
# model.model.21.cv2.bn.weight False
# model.model.21.cv2.bn.bias False
# model.model.21.m.0.cv1.conv.weight False
# model.model.21.m.0.cv1.bn.weight False
# model.model.21.m.0.cv1.bn.bias False
# model.model.21.m.0.cv2.conv.weight False
# model.model.21.m.0.cv2.bn.weight False
# model.model.21.m.0.cv2.bn.bias False
# model.model.21.m.1.cv1.conv.weight False
# model.model.21.m.1.cv1.bn.weight False
# model.model.21.m.1.cv1.bn.bias False
# model.model.21.m.1.cv2.conv.weight False
# model.model.21.m.1.cv2.bn.weight False
# model.model.21.m.1.cv2.bn.bias False
# model.model.21.m.2.cv1.conv.weight False
# model.model.21.m.2.cv1.bn.weight False
# model.model.21.m.2.cv1.bn.bias False
# model.model.21.m.2.cv2.conv.weight False
# model.model.21.m.2.cv2.bn.weight False
# model.model.21.m.2.cv2.bn.bias False
# model.model.22.cv2.0.0.conv.weight False
# model.model.22.cv2.0.0.bn.weight False
# model.model.22.cv2.0.0.bn.bias False
# model.model.22.cv2.0.1.conv.weight False
# model.model.22.cv2.0.1.bn.weight False
# model.model.22.cv2.0.1.bn.bias False
# model.model.22.cv2.0.2.weight False
# model.model.22.cv2.0.2.bias False
# model.model.22.cv2.1.0.conv.weight False
# model.model.22.cv2.1.0.bn.weight False
# model.model.22.cv2.1.0.bn.bias False
# model.model.22.cv2.1.1.conv.weight False
# model.model.22.cv2.1.1.bn.weight False
# model.model.22.cv2.1.1.bn.bias False
# model.model.22.cv2.1.2.weight False
# model.model.22.cv2.1.2.bias False
# model.model.22.cv2.2.0.conv.weight False
# model.model.22.cv2.2.0.bn.weight False
# model.model.22.cv2.2.0.bn.bias False
# model.model.22.cv2.2.1.conv.weight False
# model.model.22.cv2.2.1.bn.weight False
# model.model.22.cv2.2.1.bn.bias False
# model.model.22.cv2.2.2.weight False
# model.model.22.cv2.2.2.bias False
# model.model.22.cv3.0.0.conv.weight False
# model.model.22.cv3.0.0.bn.weight False
# model.model.22.cv3.0.0.bn.bias False
# model.model.22.cv3.0.1.conv.weight False
# model.model.22.cv3.0.1.bn.weight False
# model.model.22.cv3.0.1.bn.bias False
# model.model.22.cv3.0.2.weight False
# model.model.22.cv3.0.2.bias False
# model.model.22.cv3.1.0.conv.weight False
# model.model.22.cv3.1.0.bn.weight False
# model.model.22.cv3.1.0.bn.bias False
# model.model.22.cv3.1.1.conv.weight False
# model.model.22.cv3.1.1.bn.weight False
# model.model.22.cv3.1.1.bn.bias False
# model.model.22.cv3.1.2.weight False
# model.model.22.cv3.1.2.bias False
# model.model.22.cv3.2.0.conv.weight False
# model.model.22.cv3.2.0.bn.weight False
# model.model.22.cv3.2.0.bn.bias False
# model.model.22.cv3.2.1.conv.weight False
# model.model.22.cv3.2.1.bn.weight False
# model.model.22.cv3.2.1.bn.bias False
# model.model.22.cv3.2.2.weight False
# model.model.22.cv3.2.2.bias False
# model.model.22.dfl.conv.weight False

# %%
model_2 = YOLO("/home/areebadnan/Areeb_code/work/Atheritia/All_models/Large/coco_base_finetune_17logo_L.pt")
#model_1 = YOLO("/home/areebadnan/Areeb_code/work/Atheritia/ultralytics/47_(10)_logos_head_17logosbase_L/train3/weights/best.pt")

# %%
compare_dicts(model_1.state_dict(), model_2.state_dict())
# Out:
# Weights for parameter 'model.model.22.cv2.1.0.bn.bias' are different.
# Weights for parameter 'model.model.22.cv2.1.1.bn.bias' are different.
# Weights for parameter 'model.model.8.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.21.cv1.bn.bias' are different.
# Weights for parameter 'model.model.22.cv2.1.0.bn.weight' are different.
# Weights for parameter 'model.model.3.bn.running_var' are different.
# Weights for parameter 'model.model.8.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.8.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.0.cv2.bn.bias' are different.
# Weights for parameter 'model.model.22.cv2.0.1.conv.weight' are different.
# Weights for parameter 'model.model.4.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.1.cv2.bn.bias' are different.
# Weights for parameter 'model.model.21.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.16.bn.weight' are different.
# Weights for parameter 'model.model.21.m.0.cv1.bn.bias' are different.
# Weights for parameter 'model.model.22.cv2.1.1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.2.1.conv.weight' are different.
# Weights for parameter 'model.model.21.m.1.cv2.conv.weight' are different.
# Weights for parameter 'model.model.6.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.15.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.1.cv1.bn.bias' are different.
# Weights for parameter 'model.model.22.cv3.2.0.bn.weight' are different.
# Weights for parameter 'model.model.18.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.21.cv1.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.0.1.bn.running_var' are different.
# Weights for parameter 'model.model.21.m.2.cv2.conv.weight' are different.
# Weights for parameter 'model.model.12.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.1.2.bias' are different.
# Weights for parameter 'model.model.4.m.3.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.8.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.2.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.2.cv1.conv.weight' are different.
# Weights for parameter 'model.model.22.cv2.0.1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.2.2.weight' are different.
# Weights for parameter 'model.model.15.cv1.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.1.1.bn.bias' are different.
# Weights for parameter 'model.model.21.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.21.m.0.cv2.conv.weight' are different.
# Weights for parameter 'model.model.6.m.3.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.4.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.0.0.conv.weight' are different.
# Weights for parameter 'model.model.7.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.0.0.bn.weight' are different.
# Weights for parameter 'model.model.22.cv2.2.0.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.2.1.bn.running_mean' are different.
# Weights for parameter 'model.model.15.cv1.bn.weight' are different.
# Weights for parameter 'model.model.22.cv2.0.1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.0.cv1.bn.weight' are different.
# Weights for parameter 'model.model.12.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.1.cv1.conv.weight' are different.
# Weights for parameter 'model.model.6.m.4.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.5.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.0.0.bn.running_mean' are different.
# Weights for parameter 'model.model.15.cv2.bn.bias' are different.
# Weights for parameter 'model.model.22.cv2.0.0.bn.bias' are different.
# Weights for parameter 'model.model.6.m.5.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.2.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.0.0.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.1.0.conv.weight' are different.
# Weights for parameter 'model.model.4.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.0.cv2.conv.weight' are different.
# Weights for parameter 'model.model.18.m.2.cv2.bn.weight' are different.
# Weights for parameter 'model.model.2.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.15.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.0.1.conv.weight' are different.
# Weights for parameter 'model.model.18.m.2.cv2.bn.bias' are different.
# Weights for parameter 'model.model.4.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.4.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.1.1.conv.weight' are different.
# Weights for parameter 'model.model.15.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.1.cv1.bn.weight' are different.
# Weights for parameter 'model.model.15.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.2.cv1.bn.weight' are different.
# Weights for parameter 'model.model.21.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.6.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.2.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.0.0.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.5.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.2.1.conv.weight' are different.
# Weights for parameter 'model.model.15.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.2.0.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.9.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.2.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.0.0.bn.bias' are different.
# Weights for parameter 'model.model.12.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.6.m.3.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.0.0.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.2.0.bn.running_mean' are different.
# Weights for parameter 'model.model.18.cv2.conv.weight' are different.
# Weights for parameter 'model.model.21.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.2.0.conv.weight' are different.
# Weights for parameter 'model.model.6.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.19.bn.running_mean' are different.
# Weights for parameter 'model.model.21.cv2.conv.weight' are different.
# Weights for parameter 'model.model.18.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.2.cv2.bn.bias' are different.
# Weights for parameter 'model.model.21.cv2.bn.bias' are different.
# Weights for parameter 'model.model.6.m.3.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.4.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.0.cv2.bn.weight' are different.
# Weights for parameter 'model.model.22.cv3.0.1.bn.weight' are different.
# Weights for parameter 'model.model.18.m.1.cv1.conv.weight' are different.
# Weights for parameter 'model.model.4.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.0.cv1.bn.weight' are different.
# Weights for parameter 'model.model.2.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.cv2.bn.weight' are different.
# Weights for parameter 'model.model.4.m.5.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.4.m.3.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.7.bn.running_mean' are different.
# Weights for parameter 'model.model.18.cv1.bn.weight' are different.
# Weights for parameter 'model.model.15.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.2.cv2.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.0.0.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.2.0.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.0.2.bias' are different.
# Weights for parameter 'model.model.8.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.0.1.bn.weight' are different.
# Weights for parameter 'model.model.12.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.6.m.5.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.8.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.4.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.19.conv.weight' are different.
# Weights for parameter 'model.model.21.m.1.cv1.conv.weight' are different.
# Weights for parameter 'model.model.18.m.1.cv1.bn.bias' are different.
# Weights for parameter 'model.model.4.m.4.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.15.cv2.bn.weight' are different.
# Weights for parameter 'model.model.9.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.4.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.2.cv1.bn.weight' are different.
# Weights for parameter 'model.model.6.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.12.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.0.cv2.bn.bias' are different.
# Weights for parameter 'model.model.16.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.1.1.conv.weight' are different.
# Weights for parameter 'model.model.4.m.5.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.6.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.9.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.2.2.weight' are different.
# Weights for parameter 'model.model.21.m.2.cv2.bn.bias' are different.
# Weights for parameter 'model.model.4.m.4.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.1.cv2.conv.weight' are different.
# Weights for parameter 'model.model.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.18.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.2.0.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.1.0.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.0.1.bn.running_mean' are different.
# Weights for parameter 'model.model.0.bn.running_mean' are different.
# Weights for parameter 'model.model.6.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.6.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.1.cv2.bn.weight' are different.
# Weights for parameter 'model.model.6.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.2.2.bias' are different.
# Weights for parameter 'model.model.4.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.1.0.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.1.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.1.0.bn.running_mean' are different.
# Weights for parameter 'model.model.19.bn.running_var' are different.
# Weights for parameter 'model.model.4.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.21.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.18.cv1.bn.bias' are different.
# Weights for parameter 'model.model.6.m.4.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.cv1.conv.weight' are different.
# Weights for parameter 'model.model.21.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.0.1.bn.bias' are different.
# Weights for parameter 'model.model.22.cv3.1.0.bn.weight' are different.
# Weights for parameter 'model.model.15.cv1.bn.bias' are different.
# Weights for parameter 'model.model.21.m.1.cv2.bn.bias' are different.
# Weights for parameter 'model.model.4.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.0.0.bn.weight' are different.
# Weights for parameter 'model.model.4.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.2.1.bn.bias' are different.
# Weights for parameter 'model.model.8.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.21.m.0.cv1.conv.weight' are different.
# Weights for parameter 'model.model.2.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.18.cv2.bn.bias' are different.
# Weights for parameter 'model.model.9.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.1.bn.running_var' are different.
# Weights for parameter 'model.model.4.m.3.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.0.cv1.conv.weight' are different.
# Weights for parameter 'model.model.2.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.0.cv1.bn.bias' are different.
# Weights for parameter 'model.model.0.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.2.1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.0.2.bias' are different.
# Weights for parameter 'model.model.8.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.0.cv2.bn.weight' are different.
# Weights for parameter 'model.model.22.cv2.1.1.bn.running_var' are different.
# Weights for parameter 'model.model.21.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.21.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.4.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.2.cv1.bn.bias' are different.
# Weights for parameter 'model.model.1.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.15.cv2.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.1.0.bn.bias' are different.
# Weights for parameter 'model.model.4.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.2.1.bn.weight' are different.
# Weights for parameter 'model.model.22.cv3.1.1.bn.running_mean' are different.
# Weights for parameter 'model.model.8.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.18.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.12.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.12.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.2.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv2.0.2.weight' are different.
# Weights for parameter 'model.model.22.cv3.1.1.bn.weight' are different.
# Weights for parameter 'model.model.4.m.3.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.1.cv1.bn.weight' are different.
# Weights for parameter 'model.model.22.cv2.2.0.bn.bias' are different.
# Weights for parameter 'model.model.12.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.2.cv1.conv.weight' are different.
# Weights for parameter 'model.model.6.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.16.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.2.cv1.bn.bias' are different.
# Weights for parameter 'model.model.6.m.3.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.2.1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.4.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.4.m.4.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.0.cv2.bn.bias' are different.
# Weights for parameter 'model.model.16.bn.bias' are different.
# Weights for parameter 'model.model.18.m.0.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.5.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.15.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.2.2.bias' are different.
# Weights for parameter 'model.model.16.conv.weight' are different.
# Weights for parameter 'model.model.22.cv3.1.1.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.21.m.2.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.1.0.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.4.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.8.m.2.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.18.m.2.cv1.bn.bias' are different.
# Weights for parameter 'model.model.12.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.0.cv1.conv.weight' are different.
# Weights for parameter 'model.model.15.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.1.0.conv.weight' are different.
# Weights for parameter 'model.model.22.cv2.2.1.bn.running_var' are different.
# Weights for parameter 'model.model.18.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.5.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv3.2.0.bn.bias' are different.
# Weights for parameter 'model.model.4.m.5.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.1.2.bias' are different.
# Weights for parameter 'model.model.15.m.0.cv1.bn.bias' are different.
# Weights for parameter 'model.model.15.m.1.cv1.bn.bias' are different.
# Weights for parameter 'model.model.4.m.5.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.22.cv3.1.2.weight' are different.
# Weights for parameter 'model.model.15.m.2.cv2.bn.weight' are different.
# Weights for parameter 'model.model.22.cv3.0.2.weight' are different.
# Weights for parameter 'model.model.2.m.1.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.6.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.0.cv2.conv.weight' are different.
# Weights for parameter 'model.model.4.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.6.m.0.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.12.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.2.m.0.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.2.m.1.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.15.m.2.cv2.conv.weight' are different.
# Weights for parameter 'model.model.15.m.2.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.21.m.2.cv1.conv.weight' are different.
# Weights for parameter 'model.model.3.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.1.1.bn.weight' are different.
# Weights for parameter 'model.model.22.cv3.0.1.bn.bias' are different.
# Weights for parameter 'model.model.18.m.1.cv2.bn.bias' are different.
# Weights for parameter 'model.model.2.m.0.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.21.m.1.cv2.bn.running_mean' are different.
# Weights for parameter 'model.model.18.m.1.cv2.bn.weight' are different.
# Weights for parameter 'model.model.15.m.1.cv2.conv.weight' are different.
# Weights for parameter 'model.model.4.m.4.cv2.bn.running_var' are different.
# Weights for parameter 'model.model.15.cv1.bn.running_var' are different.
# Weights for parameter 'model.model.21.cv1.bn.running_mean' are different.
# Weights for parameter 'model.model.22.cv2.1.2.weight' are different.
# Weights for parameter 'model.model.15.m.1.cv1.bn.running_var' are different.

# %%
model_1_state_dict_head = dict()
model_2_state_dict_head = dict()

# %%
model_1_state_dict_base = dict()  # Initialize a new dictionary to hold the copied state

# Loop through all layers from model.0 to model.21
for k, v in model_1.state_dict().items():
    # Loop from 0 to 21 to cover model.0 to model.21
    for i in range(22):  # Use range(22) to cover indices from 0 to 21
        prefix = f"model.model.{i}."  # Add a period at the end to avoid partial matches
        if k.startswith(prefix):
            # Copy the state dictionary to the new dictionary
            model_1_state_dict_base[k] = v
            break  # Stop the inner loop once a match is found

# Now, model_1_state_dict contains all the state dictionaries from model.0 to model.21

# %%
for k, v in model_1.state_dict().items():
  if k.startswith("model.model.22"):
    model_1_state_dict_head[k.replace("model.22", "model.31")] = v

# %%
layers_to_save = [13, 14, 15, 16, 17, 18, 19, 20, 21]
model_2_state_dict_base = dict()

# Iterate over the model's state dictionary
for k, v in model_2.state_dict().items():
    # Check if the layer matches any in layers_to_save
    for layer in layers_to_save:
        if k.startswith(f"model.model.{layer}"):
            # Rename the layer by shifting the index (e.g., model.13 -> model.22)
            new_layer_index = layer + 9
            new_key = k.replace(f"model.model.{layer}", f"model.model.{new_layer_index}")
            
            # Store the new key-value pair in the new state dict
            model_2_state_dict_base[new_key] = v

# %%
for k, v in model_2.state_dict().items():
  if k.startswith("model.model.22"):
    model_2_state_dict_head[k.replace("model.22", "model.32")] = v

# %%
model_yaml.load_state_dict(model_1_state_dict_base, strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['model.model.24.cv1.conv.weight', 'model.model.24.cv1.bn.weight', 'model.model.24.cv1.bn.bias', 'model.model.24.cv1.bn.running_mean', 'model.model.24.cv1.bn.running_var', 'model.model.24.cv2.conv.weight', 'model.model.24.cv2.bn.weight', 'model.model.24.cv2.bn.bias', 'model.model.24.cv2.bn.running_mean', 'model.model.24.cv2.bn.running_var', 'model.model.24.m.0.cv1.conv.weight', 'model.model.24.m.0.cv1.bn.weight', 'model.model.24.m.0.cv1.bn.bias', 'model.model.24.m.0.cv1.bn.running_mean', 'model.model.24.m.0.cv1.bn.running_var', 'model.model.24.m.0.cv2.conv.weight', 'model.model.24.m.0.cv2.bn.weight', 'model.model.24.m.0.cv2.bn.bias', 'model.model.24.m.0.cv2.bn.running_mean', 'model.model.24.m.0.cv2.bn.running_var', 'model.model.24.m.1.cv1.conv.weight', 'model.model.24.m.1.cv1.bn.weight', 'model.model.24.m.1.cv1.bn.bias', 'model.model.24.m.1.cv1.bn.running_mean', 'model.model.24.m.1.cv1.bn.running_var', 'model.model.24.m.1.cv2.conv.weight', 'model.model.24.m.1.cv2.bn.weight', 'model.model.24.m.1.cv2.bn.bias', 'model.model.24.m.1.cv2.bn.running_mean', 'model.model.24.m.1.cv2.bn.running_var', 'model.model.24.m.2.cv1.conv.weight', 'model.model.24.m.2.cv1.bn.weight', 'model.model.24.m.2.cv1.bn.bias', 'model.model.24.m.2.cv1.bn.running_mean', 'model.model.24.m.2.cv1.bn.running_var', 'model.model.24.m.2.cv2.conv.weight', 'model.model.24.m.2.cv2.bn.weight', 'model.model.24.m.2.cv2.bn.bias', 'model.model.24.m.2.cv2.bn.running_mean', 'model.model.24.m.2.cv2.bn.running_var', 'model.model.25.conv.weight', 'model.model.25.bn.weight', 'model.model.25.bn.bias', 'model.model.25.bn.running_mean', 'model.model.25.bn.running_var', 'model.model.27.cv1.conv.weight', 'model.model.27.cv1.bn.weight', 'model.model.27.cv1.bn.bias', 'model.model.27.cv1.bn.running_mean', 'model.model.27.cv1.bn.running_var', 'model.model.27.cv2.conv.weight', 'model.model.27.cv2.bn.weight', 'model.model.27.cv2.bn.bias', 'model.model.27.cv2.bn.running_mean', 'model.model.27.cv2.bn.running_var', 'model.model.27.m.0.cv1.conv.weight', 'model.model.27.m.0.cv1.bn.weight', 'model.model.27.m.0.cv1.bn.bias', 'model.model.27.m.0.cv1.bn.running_mean', 'model.model.27.m.0.cv1.bn.running_var', 'model.model.27.m.0.cv2.conv.weight', 'model.model.27.m.0.cv2.bn.weight', 'model.model.27.m.0.cv2.bn.bias', 'model.model.27.m.0.cv2.bn.running_mean', 'model.model.27.m.0.cv2.bn.running_var', 'model.model.27.m.1.cv1.conv.weight', 'model.model.27.m.1.cv1.bn.weight', 'model.model.27.m.1.cv1.bn.bias', 'model.model.27.m.1.cv1.bn.running_mean', 'model.model.27.m.1.cv1.bn.running_var', 'model.model.27.m.1.cv2.conv.weight', 'model.model.27.m.1.cv2.bn.weight', 'model.model.27.m.1.cv2.bn.bias', 'model.model.27.m.1.cv2.bn.running_mean', 'model.model.27.m.1.cv2.bn.running_var', 'model.model.27.m.2.cv1.conv.weight', 'model.model.27.m.2.cv1.bn.weight', 'model.model.27.m.2.cv1.bn.bias', 'model.model.27.m.2.cv1.bn.running_mean', 'model.model.27.m.2.cv1.bn.running_var', 'model.model.27.m.2.cv2.conv.weight', 'model.model.27.m.2.cv2.bn.weight', 'model.model.27.m.2.cv2.bn.bias', 'model.model.27.m.2.cv2.bn.running_mean', 'model.model.27.m.2.cv2.bn.running_var', 'model.model.28.conv.weight', 'model.model.28.bn.weight', 'model.model.28.bn.bias', 'model.model.28.bn.running_mean', 'model.model.28.bn.running_var', 'model.model.30.cv1.conv.weight', 'model.model.30.cv1.bn.weight', 'model.model.30.cv1.bn.bias', 'model.model.30.cv1.bn.running_mean', 'model.model.30.cv1.bn.running_var', 'model.model.30.cv2.conv.weight', 'model.model.30.cv2.bn.weight', 'model.model.30.cv2.bn.bias', 'model.model.30.cv2.bn.running_mean', 'model.model.30.cv2.bn.running_var', 'model.model.30.m.0.cv1.conv.weight', 'model.model.30.m.0.cv1.bn.weight', 'model.model.30.m.0.cv1.bn.bias', 'model.model.30.m.0.cv1.bn.running_mean', 'model.model.30.m.0.cv1.bn.running_var', 'model.model.30.m.0.cv2.conv.weight', 'model.model.30.m.0.cv2.bn.weight', 'model.model.30.m.0.cv2.bn.bias', 'model.model.30.m.0.cv2.bn.running_mean', 'model. ...

# %%
model_yaml.load_state_dict(model_2_state_dict_base, strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['model.model.0.conv.weight', 'model.model.0.bn.weight', 'model.model.0.bn.bias', 'model.model.0.bn.running_mean', 'model.model.0.bn.running_var', 'model.model.1.conv.weight', 'model.model.1.bn.weight', 'model.model.1.bn.bias', 'model.model.1.bn.running_mean', 'model.model.1.bn.running_var', 'model.model.2.cv1.conv.weight', 'model.model.2.cv1.bn.weight', 'model.model.2.cv1.bn.bias', 'model.model.2.cv1.bn.running_mean', 'model.model.2.cv1.bn.running_var', 'model.model.2.cv2.conv.weight', 'model.model.2.cv2.bn.weight', 'model.model.2.cv2.bn.bias', 'model.model.2.cv2.bn.running_mean', 'model.model.2.cv2.bn.running_var', 'model.model.2.m.0.cv1.conv.weight', 'model.model.2.m.0.cv1.bn.weight', 'model.model.2.m.0.cv1.bn.bias', 'model.model.2.m.0.cv1.bn.running_mean', 'model.model.2.m.0.cv1.bn.running_var', 'model.model.2.m.0.cv2.conv.weight', 'model.model.2.m.0.cv2.bn.weight', 'model.model.2.m.0.cv2.bn.bias', 'model.model.2.m.0.cv2.bn.running_mean', 'model.model.2.m.0.cv2.bn.running_var', 'model.model.2.m.1.cv1.conv.weight', 'model.model.2.m.1.cv1.bn.weight', 'model.model.2.m.1.cv1.bn.bias', 'model.model.2.m.1.cv1.bn.running_mean', 'model.model.2.m.1.cv1.bn.running_var', 'model.model.2.m.1.cv2.conv.weight', 'model.model.2.m.1.cv2.bn.weight', 'model.model.2.m.1.cv2.bn.bias', 'model.model.2.m.1.cv2.bn.running_mean', 'model.model.2.m.1.cv2.bn.running_var', 'model.model.2.m.2.cv1.conv.weight', 'model.model.2.m.2.cv1.bn.weight', 'model.model.2.m.2.cv1.bn.bias', 'model.model.2.m.2.cv1.bn.running_mean', 'model.model.2.m.2.cv1.bn.running_var', 'model.model.2.m.2.cv2.conv.weight', 'model.model.2.m.2.cv2.bn.weight', 'model.model.2.m.2.cv2.bn.bias', 'model.model.2.m.2.cv2.bn.running_mean', 'model.model.2.m.2.cv2.bn.running_var', 'model.model.3.conv.weight', 'model.model.3.bn.weight', 'model.model.3.bn.bias', 'model.model.3.bn.running_mean', 'model.model.3.bn.running_var', 'model.model.4.cv1.conv.weight', 'model.model.4.cv1.bn.weight', 'model.model.4.cv1.bn.bias', 'model.model.4.cv1.bn.running_mean', 'model.model.4.cv1.bn.running_var', 'model.model.4.cv2.conv.weight', 'model.model.4.cv2.bn.weight', 'model.model.4.cv2.bn.bias', 'model.model.4.cv2.bn.running_mean', 'model.model.4.cv2.bn.running_var', 'model.model.4.m.0.cv1.conv.weight', 'model.model.4.m.0.cv1.bn.weight', 'model.model.4.m.0.cv1.bn.bias', 'model.model.4.m.0.cv1.bn.running_mean', 'model.model.4.m.0.cv1.bn.running_var', 'model.model.4.m.0.cv2.conv.weight', 'model.model.4.m.0.cv2.bn.weight', 'model.model.4.m.0.cv2.bn.bias', 'model.model.4.m.0.cv2.bn.running_mean', 'model.model.4.m.0.cv2.bn.running_var', 'model.model.4.m.1.cv1.conv.weight', 'model.model.4.m.1.cv1.bn.weight', 'model.model.4.m.1.cv1.bn.bias', 'model.model.4.m.1.cv1.bn.running_mean', 'model.model.4.m.1.cv1.bn.running_var', 'model.model.4.m.1.cv2.conv.weight', 'model.model.4.m.1.cv2.bn.weight', 'model.model.4.m.1.cv2.bn.bias', 'model.model.4.m.1.cv2.bn.running_mean', 'model.model.4.m.1.cv2.bn.running_var', 'model.model.4.m.2.cv1.conv.weight', 'model.model.4.m.2.cv1.bn.weight', 'model.model.4.m.2.cv1.bn.bias', 'model.model.4.m.2.cv1.bn.running_mean', 'model.model.4.m.2.cv1.bn.running_var', 'model.model.4.m.2.cv2.conv.weight', 'model.model.4.m.2.cv2.bn.weight', 'model.model.4.m.2.cv2.bn.bias', 'model.model.4.m.2.cv2.bn.running_mean', 'model.model.4.m.2.cv2.bn.running_var', 'model.model.4.m.3.cv1.conv.weight', 'model.model.4.m.3.cv1.bn.weight', 'model.model.4.m.3.cv1.bn.bias', 'model.model.4.m.3.cv1.bn.running_mean', 'model.model.4.m.3.cv1.bn.running_var', 'model.model.4.m.3.cv2.conv.weight', 'model.model.4.m.3.cv2.bn.weight', 'model.model.4.m.3.cv2.bn.bias', 'model.model.4.m.3.cv2.bn.running_mean', 'model.model.4.m.3.cv2.bn.running_var', 'model.model.4.m.4.cv1.conv.weight', 'model.model.4.m.4.cv1.bn.weight', 'model.model.4.m.4.cv1.bn.bias', 'model.model.4.m.4.cv1.bn.running_mean', 'model.model.4.m.4.cv1.bn.running_var', 'model.model.4.m.4.cv2.conv.weight', 'model.model.4.m.4.cv2.bn.weight', 'mod ...

# %%
model_yaml.load_state_dict(model_1_state_dict_head,strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['model.model.0.conv.weight', 'model.model.0.bn.weight', 'model.model.0.bn.bias', 'model.model.0.bn.running_mean', 'model.model.0.bn.running_var', 'model.model.1.conv.weight', 'model.model.1.bn.weight', 'model.model.1.bn.bias', 'model.model.1.bn.running_mean', 'model.model.1.bn.running_var', 'model.model.2.cv1.conv.weight', 'model.model.2.cv1.bn.weight', 'model.model.2.cv1.bn.bias', 'model.model.2.cv1.bn.running_mean', 'model.model.2.cv1.bn.running_var', 'model.model.2.cv2.conv.weight', 'model.model.2.cv2.bn.weight', 'model.model.2.cv2.bn.bias', 'model.model.2.cv2.bn.running_mean', 'model.model.2.cv2.bn.running_var', 'model.model.2.m.0.cv1.conv.weight', 'model.model.2.m.0.cv1.bn.weight', 'model.model.2.m.0.cv1.bn.bias', 'model.model.2.m.0.cv1.bn.running_mean', 'model.model.2.m.0.cv1.bn.running_var', 'model.model.2.m.0.cv2.conv.weight', 'model.model.2.m.0.cv2.bn.weight', 'model.model.2.m.0.cv2.bn.bias', 'model.model.2.m.0.cv2.bn.running_mean', 'model.model.2.m.0.cv2.bn.running_var', 'model.model.2.m.1.cv1.conv.weight', 'model.model.2.m.1.cv1.bn.weight', 'model.model.2.m.1.cv1.bn.bias', 'model.model.2.m.1.cv1.bn.running_mean', 'model.model.2.m.1.cv1.bn.running_var', 'model.model.2.m.1.cv2.conv.weight', 'model.model.2.m.1.cv2.bn.weight', 'model.model.2.m.1.cv2.bn.bias', 'model.model.2.m.1.cv2.bn.running_mean', 'model.model.2.m.1.cv2.bn.running_var', 'model.model.2.m.2.cv1.conv.weight', 'model.model.2.m.2.cv1.bn.weight', 'model.model.2.m.2.cv1.bn.bias', 'model.model.2.m.2.cv1.bn.running_mean', 'model.model.2.m.2.cv1.bn.running_var', 'model.model.2.m.2.cv2.conv.weight', 'model.model.2.m.2.cv2.bn.weight', 'model.model.2.m.2.cv2.bn.bias', 'model.model.2.m.2.cv2.bn.running_mean', 'model.model.2.m.2.cv2.bn.running_var', 'model.model.3.conv.weight', 'model.model.3.bn.weight', 'model.model.3.bn.bias', 'model.model.3.bn.running_mean', 'model.model.3.bn.running_var', 'model.model.4.cv1.conv.weight', 'model.model.4.cv1.bn.weight', 'model.model.4.cv1.bn.bias', 'model.model.4.cv1.bn.running_mean', 'model.model.4.cv1.bn.running_var', 'model.model.4.cv2.conv.weight', 'model.model.4.cv2.bn.weight', 'model.model.4.cv2.bn.bias', 'model.model.4.cv2.bn.running_mean', 'model.model.4.cv2.bn.running_var', 'model.model.4.m.0.cv1.conv.weight', 'model.model.4.m.0.cv1.bn.weight', 'model.model.4.m.0.cv1.bn.bias', 'model.model.4.m.0.cv1.bn.running_mean', 'model.model.4.m.0.cv1.bn.running_var', 'model.model.4.m.0.cv2.conv.weight', 'model.model.4.m.0.cv2.bn.weight', 'model.model.4.m.0.cv2.bn.bias', 'model.model.4.m.0.cv2.bn.running_mean', 'model.model.4.m.0.cv2.bn.running_var', 'model.model.4.m.1.cv1.conv.weight', 'model.model.4.m.1.cv1.bn.weight', 'model.model.4.m.1.cv1.bn.bias', 'model.model.4.m.1.cv1.bn.running_mean', 'model.model.4.m.1.cv1.bn.running_var', 'model.model.4.m.1.cv2.conv.weight', 'model.model.4.m.1.cv2.bn.weight', 'model.model.4.m.1.cv2.bn.bias', 'model.model.4.m.1.cv2.bn.running_mean', 'model.model.4.m.1.cv2.bn.running_var', 'model.model.4.m.2.cv1.conv.weight', 'model.model.4.m.2.cv1.bn.weight', 'model.model.4.m.2.cv1.bn.bias', 'model.model.4.m.2.cv1.bn.running_mean', 'model.model.4.m.2.cv1.bn.running_var', 'model.model.4.m.2.cv2.conv.weight', 'model.model.4.m.2.cv2.bn.weight', 'model.model.4.m.2.cv2.bn.bias', 'model.model.4.m.2.cv2.bn.running_mean', 'model.model.4.m.2.cv2.bn.running_var', 'model.model.4.m.3.cv1.conv.weight', 'model.model.4.m.3.cv1.bn.weight', 'model.model.4.m.3.cv1.bn.bias', 'model.model.4.m.3.cv1.bn.running_mean', 'model.model.4.m.3.cv1.bn.running_var', 'model.model.4.m.3.cv2.conv.weight', 'model.model.4.m.3.cv2.bn.weight', 'model.model.4.m.3.cv2.bn.bias', 'model.model.4.m.3.cv2.bn.running_mean', 'model.model.4.m.3.cv2.bn.running_var', 'model.model.4.m.4.cv1.conv.weight', 'model.model.4.m.4.cv1.bn.weight', 'model.model.4.m.4.cv1.bn.bias', 'model.model.4.m.4.cv1.bn.running_mean', 'model.model.4.m.4.cv1.bn.running_var', 'model.model.4.m.4.cv2.conv.weight', 'model.model.4.m.4.cv2.bn.weight', 'mod ...

# %%
model_yaml.load_state_dict(model_2_state_dict_head,strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['model.model.0.conv.weight', 'model.model.0.bn.weight', 'model.model.0.bn.bias', 'model.model.0.bn.running_mean', 'model.model.0.bn.running_var', 'model.model.1.conv.weight', 'model.model.1.bn.weight', 'model.model.1.bn.bias', 'model.model.1.bn.running_mean', 'model.model.1.bn.running_var', 'model.model.2.cv1.conv.weight', 'model.model.2.cv1.bn.weight', 'model.model.2.cv1.bn.bias', 'model.model.2.cv1.bn.running_mean', 'model.model.2.cv1.bn.running_var', 'model.model.2.cv2.conv.weight', 'model.model.2.cv2.bn.weight', 'model.model.2.cv2.bn.bias', 'model.model.2.cv2.bn.running_mean', 'model.model.2.cv2.bn.running_var', 'model.model.2.m.0.cv1.conv.weight', 'model.model.2.m.0.cv1.bn.weight', 'model.model.2.m.0.cv1.bn.bias', 'model.model.2.m.0.cv1.bn.running_mean', 'model.model.2.m.0.cv1.bn.running_var', 'model.model.2.m.0.cv2.conv.weight', 'model.model.2.m.0.cv2.bn.weight', 'model.model.2.m.0.cv2.bn.bias', 'model.model.2.m.0.cv2.bn.running_mean', 'model.model.2.m.0.cv2.bn.running_var', 'model.model.2.m.1.cv1.conv.weight', 'model.model.2.m.1.cv1.bn.weight', 'model.model.2.m.1.cv1.bn.bias', 'model.model.2.m.1.cv1.bn.running_mean', 'model.model.2.m.1.cv1.bn.running_var', 'model.model.2.m.1.cv2.conv.weight', 'model.model.2.m.1.cv2.bn.weight', 'model.model.2.m.1.cv2.bn.bias', 'model.model.2.m.1.cv2.bn.running_mean', 'model.model.2.m.1.cv2.bn.running_var', 'model.model.2.m.2.cv1.conv.weight', 'model.model.2.m.2.cv1.bn.weight', 'model.model.2.m.2.cv1.bn.bias', 'model.model.2.m.2.cv1.bn.running_mean', 'model.model.2.m.2.cv1.bn.running_var', 'model.model.2.m.2.cv2.conv.weight', 'model.model.2.m.2.cv2.bn.weight', 'model.model.2.m.2.cv2.bn.bias', 'model.model.2.m.2.cv2.bn.running_mean', 'model.model.2.m.2.cv2.bn.running_var', 'model.model.3.conv.weight', 'model.model.3.bn.weight', 'model.model.3.bn.bias', 'model.model.3.bn.running_mean', 'model.model.3.bn.running_var', 'model.model.4.cv1.conv.weight', 'model.model.4.cv1.bn.weight', 'model.model.4.cv1.bn.bias', 'model.model.4.cv1.bn.running_mean', 'model.model.4.cv1.bn.running_var', 'model.model.4.cv2.conv.weight', 'model.model.4.cv2.bn.weight', 'model.model.4.cv2.bn.bias', 'model.model.4.cv2.bn.running_mean', 'model.model.4.cv2.bn.running_var', 'model.model.4.m.0.cv1.conv.weight', 'model.model.4.m.0.cv1.bn.weight', 'model.model.4.m.0.cv1.bn.bias', 'model.model.4.m.0.cv1.bn.running_mean', 'model.model.4.m.0.cv1.bn.running_var', 'model.model.4.m.0.cv2.conv.weight', 'model.model.4.m.0.cv2.bn.weight', 'model.model.4.m.0.cv2.bn.bias', 'model.model.4.m.0.cv2.bn.running_mean', 'model.model.4.m.0.cv2.bn.running_var', 'model.model.4.m.1.cv1.conv.weight', 'model.model.4.m.1.cv1.bn.weight', 'model.model.4.m.1.cv1.bn.bias', 'model.model.4.m.1.cv1.bn.running_mean', 'model.model.4.m.1.cv1.bn.running_var', 'model.model.4.m.1.cv2.conv.weight', 'model.model.4.m.1.cv2.bn.weight', 'model.model.4.m.1.cv2.bn.bias', 'model.model.4.m.1.cv2.bn.running_mean', 'model.model.4.m.1.cv2.bn.running_var', 'model.model.4.m.2.cv1.conv.weight', 'model.model.4.m.2.cv1.bn.weight', 'model.model.4.m.2.cv1.bn.bias', 'model.model.4.m.2.cv1.bn.running_mean', 'model.model.4.m.2.cv1.bn.running_var', 'model.model.4.m.2.cv2.conv.weight', 'model.model.4.m.2.cv2.bn.weight', 'model.model.4.m.2.cv2.bn.bias', 'model.model.4.m.2.cv2.bn.running_mean', 'model.model.4.m.2.cv2.bn.running_var', 'model.model.4.m.3.cv1.conv.weight', 'model.model.4.m.3.cv1.bn.weight', 'model.model.4.m.3.cv1.bn.bias', 'model.model.4.m.3.cv1.bn.running_mean', 'model.model.4.m.3.cv1.bn.running_var', 'model.model.4.m.3.cv2.conv.weight', 'model.model.4.m.3.cv2.bn.weight', 'model.model.4.m.3.cv2.bn.bias', 'model.model.4.m.3.cv2.bn.running_mean', 'model.model.4.m.3.cv2.bn.running_var', 'model.model.4.m.4.cv1.conv.weight', 'model.model.4.m.4.cv1.bn.weight', 'model.model.4.m.4.cv1.bn.bias', 'model.model.4.m.4.cv1.bn.running_mean', 'model.model.4.m.4.cv1.bn.running_var', 'model.model.4.m.4.cv2.conv.weight', 'model.model.4.m.4.cv2.bn.weight', 'mod ...

# %%
import torch

def compare_model_weights(model_yaml, model_1):
    # Get the state dictionaries (parameter tensors) of both models
    model_yaml_dict = model_yaml.state_dict()
    model_1_dict = model_1.state_dict()

    # Convert dictionaries to lists of values (weights) and keys
    model_yaml_layers = list(model_yaml_dict.values())
    model_1_layers = list(model_1_dict.values())

    model_yaml_keys = list(model_yaml_dict.keys())
    model_1_keys = list(model_1_dict.keys())

    # Initialize lists to store matching and non-matching layer information
    matching_layers = []
    non_matching_layers = []

    # Compare layers based on the number of layers in the smaller model (model_1)
    for i in range(len(model_1_layers)):
        # Compare the weights of the layers
        if torch.equal(model_yaml_layers[i], model_1_layers[i]):
            matching_layers.append((i, model_yaml_keys[i], model_1_keys[i]))
        else:
            non_matching_layers.append((i, model_yaml_keys[i], model_1_keys[i]))

    # Handle the extra layers in model_yaml (if any)
    extra_layers = len(model_yaml_layers) - len(model_1_layers)
    if extra_layers > 0:
        for i in range(len(model_1_layers), len(model_yaml_layers)):
            non_matching_layers.append((i, model_yaml_keys[i], "No matching layer in model_1"))

    # Print the results
    print(f"Matching Layers: {len(matching_layers)}")
    for layer_num, yaml_key, model_1_key in matching_layers:
        print(f"Layer {layer_num}: {yaml_key} matches {model_1_key}")

    print(f"\nNon-matching Layers: {len(non_matching_layers)}")
    for layer_num, yaml_key, model_1_key in non_matching_layers:
        print(f"Layer {layer_num}: {yaml_key} does not match {model_1_key}")

    return matching_layers, non_matching_layers

# Example usage with your model_yaml and model_1
matching_layers, non_matching_layers = compare_model_weights(model_yaml, model_2)
# Out:
# Matching Layers: 276
# Layer 0: model.model.0.conv.weight matches model.model.0.conv.weight
# Layer 1: model.model.0.bn.weight matches model.model.0.bn.weight
# Layer 2: model.model.0.bn.bias matches model.model.0.bn.bias
# Layer 5: model.model.0.bn.num_batches_tracked matches model.model.0.bn.num_batches_tracked
# Layer 6: model.model.1.conv.weight matches model.model.1.conv.weight
# Layer 7: model.model.1.bn.weight matches model.model.1.bn.weight
# Layer 8: model.model.1.bn.bias matches model.model.1.bn.bias
# Layer 11: model.model.1.bn.num_batches_tracked matches model.model.1.bn.num_batches_tracked
# Layer 12: model.model.2.cv1.conv.weight matches model.model.2.cv1.conv.weight
# Layer 13: model.model.2.cv1.bn.weight matches model.model.2.cv1.bn.weight
# Layer 14: model.model.2.cv1.bn.bias matches model.model.2.cv1.bn.bias
# Layer 17: model.model.2.cv1.bn.num_batches_tracked matches model.model.2.cv1.bn.num_batches_tracked
# Layer 18: model.model.2.cv2.conv.weight matches model.model.2.cv2.conv.weight
# Layer 19: model.model.2.cv2.bn.weight matches model.model.2.cv2.bn.weight
# Layer 20: model.model.2.cv2.bn.bias matches model.model.2.cv2.bn.bias
# Layer 23: model.model.2.cv2.bn.num_batches_tracked matches model.model.2.cv2.bn.num_batches_tracked
# Layer 24: model.model.2.m.0.cv1.conv.weight matches model.model.2.m.0.cv1.conv.weight
# Layer 25: model.model.2.m.0.cv1.bn.weight matches model.model.2.m.0.cv1.bn.weight
# Layer 26: model.model.2.m.0.cv1.bn.bias matches model.model.2.m.0.cv1.bn.bias
# Layer 29: model.model.2.m.0.cv1.bn.num_batches_tracked matches model.model.2.m.0.cv1.bn.num_batches_tracked
# Layer 30: model.model.2.m.0.cv2.conv.weight matches model.model.2.m.0.cv2.conv.weight
# Layer 31: model.model.2.m.0.cv2.bn.weight matches model.model.2.m.0.cv2.bn.weight
# Layer 32: model.model.2.m.0.cv2.bn.bias matches model.model.2.m.0.cv2.bn.bias
# Layer 35: model.model.2.m.0.cv2.bn.num_batches_tracked matches model.model.2.m.0.cv2.bn.num_batches_tracked
# Layer 36: model.model.2.m.1.cv1.conv.weight matches model.model.2.m.1.cv1.conv.weight
# Layer 37: model.model.2.m.1.cv1.bn.weight matches model.model.2.m.1.cv1.bn.weight
# Layer 38: model.model.2.m.1.cv1.bn.bias matches model.model.2.m.1.cv1.bn.bias
# Layer 41: model.model.2.m.1.cv1.bn.num_batches_tracked matches model.model.2.m.1.cv1.bn.num_batches_tracked
# Layer 42: model.model.2.m.1.cv2.conv.weight matches model.model.2.m.1.cv2.conv.weight
# Layer 43: model.model.2.m.1.cv2.bn.weight matches model.model.2.m.1.cv2.bn.weight
# Layer 44: model.model.2.m.1.cv2.bn.bias matches model.model.2.m.1.cv2.bn.bias
# Layer 47: model.model.2.m.1.cv2.bn.num_batches_tracked matches model.model.2.m.1.cv2.bn.num_batches_tracked
# Layer 48: model.model.2.m.2.cv1.conv.weight matches model.model.2.m.2.cv1.conv.weight
# Layer 49: model.model.2.m.2.cv1.bn.weight matches model.model.2.m.2.cv1.bn.weight
# Layer 50: model.model.2.m.2.cv1.bn.bias matches model.model.2.m.2.cv1.bn.bias
# Layer 53: model.model.2.m.2.cv1.bn.num_batches_tracked matches model.model.2.m.2.cv1.bn.num_batches_tracked
# Layer 54: model.model.2.m.2.cv2.conv.weight matches model.model.2.m.2.cv2.conv.weight
# Layer 55: model.model.2.m.2.cv2.bn.weight matches model.model.2.m.2.cv2.bn.weight
# Layer 56: model.model.2.m.2.cv2.bn.bias matches model.model.2.m.2.cv2.bn.bias
# Layer 59: model.model.2.m.2.cv2.bn.num_batches_tracked matches model.model.2.m.2.cv2.bn.num_batches_tracked
# Layer 60: model.model.3.conv.weight matches model.model.3.conv.weight
# Layer 61: model.model.3.bn.weight matches model.model.3.bn.weight
# Layer 62: model.model.3.bn.bias matches model.model.3.bn.bias
# Layer 65: model.model.3.bn.num_batches_tracked matches model.model.3.bn.num_batches_tracked
# Layer 66: model.model.4.cv1.conv.weight matches model.model.4.cv1.conv.weight
# Layer 67: model.model.4.cv1.bn.weight matches model.model.4.cv1.bn.weight
# Layer 68: model.model.4.cv1.bn.bias matches model.model.4.cv1.bn.bias
# Layer 71: model.model.4.cv1.bn.num_batches_tracked matches model.model.4.cv1.bn.num_batches_tracked
# Layer 72: model.model.4.cv2.conv.weight matches model.model.4.cv2.conv.weight
# Layer 73: model.model.4.cv2.bn.weight matches model.model.4.cv2.bn.weight
# Layer 74: model.model.4.cv2.bn.bias matches model.model.4.cv2.bn.bias
# Layer 77: model.model.4.cv2.bn.num_batches_tracked matches model.model.4.cv2.bn.num_batches_tracked
# Layer 78: model.model.4.m.0.cv1.conv.weight matches model.model.4.m.0.cv1.conv.weight
# Layer 79: model.model.4.m.0.cv1.bn.weight matches model.model.4.m.0.cv1.bn.weight
# Layer 80: model.model.4.m.0.cv1.bn.bias matches model.model.4.m.0.cv1.bn.bias
# Layer 83: model.model.4.m.0.cv1.bn.num_batches_tracked matches model.model.4.m.0.cv1.bn.num_batches_tracked
# Layer 84: model.model.4.m.0.cv2.conv.weight matches model.model.4.m.0.cv2.conv.weight
# Layer 85: model.model.4.m.0.cv2.bn.weight matches model.model.4.m.0.cv2.bn.weight
# Layer 86: model.model.4.m.0.cv2.bn.bias matches model.model.4.m.0.cv2.bn.bias
# Layer 89: model.model.4.m.0.cv2.bn.num_batches_tracked matches model.model.4.m.0.cv2.bn.num_batches_tracked
# Layer 90: model.model.4.m.1.cv1.conv.weight matches model.model.4.m.1.cv1.conv.weight
# Layer 91: model.model.4.m.1.cv1.bn.weight matches model.model.4.m.1.cv1.bn.weight
# Layer 92: model.model.4.m.1.cv1.bn.bias matches model.model.4.m.1.cv1.bn.bias
# Layer 95: model.model.4.m.1.cv1.bn.num_batches_tracked matches model.model.4.m.1.cv1.bn.num_batches_tracked
# Layer 96: model.model.4.m.1.cv2.conv.weight matches model.model.4.m.1.cv2.conv.weight
# Layer 97: model.model.4.m.1.cv2.bn.weight matches model.model.4.m.1.cv2.bn.weight
# Layer 98: model.model.4.m.1.cv2.bn.bias matches model.model.4.m.1.cv2.bn.bias
# Layer 101: model.model.4.m.1.cv2.bn.num_batches_tracked matches model.model.4.m.1.cv2.bn.num_batches_tracked
# Layer 102: model.model.4.m.2.cv1.conv.weight matches model.model.4.m.2.cv1.conv.weight
# Layer 103: model.model.4.m.2.cv1.bn.weight matches model.model.4.m.2.cv1.bn.weight
# Layer 104: model.model.4.m.2.cv1.bn.bias matches model.model.4.m.2.cv1.bn.bias
# Layer 107: model.model.4.m.2.cv1.bn.num_batches_tracked matches model.model.4.m.2.cv1.bn.num_batches_tracked
# Layer 108: model.model.4.m.2.cv2.conv.weight matches model.model.4.m.2.cv2.conv.weight
# Layer 109: model.model.4.m.2.cv2.bn.weight matches model.model.4.m.2.cv2.bn.weight
# Layer 110: model.model.4.m.2.cv2.bn.bias matches model.model.4.m.2.cv2.bn.bias
# Layer 113: model.model.4.m.2.cv2.bn.num_batches_tracked matches model.model.4.m.2.cv2.bn.num_batches_tracked
# Layer 114: model.model.4.m.3.cv1.conv.weight matches model.model.4.m.3.cv1.conv.weight
# Layer 115: model.model.4.m.3.cv1.bn.weight matches model.model.4.m.3.cv1.bn.weight
# Layer 116: model.model.4.m.3.cv1.bn.bias matches model.model.4.m.3.cv1.bn.bias
# Layer 119: model.model.4.m.3.cv1.bn.num_batches_tracked matches model.model.4.m.3.cv1.bn.num_batches_tracked
# Layer 120: model.model.4.m.3.cv2.conv.weight matches model.model.4.m.3.cv2.conv.weight
# Layer 121: model.model.4.m.3.cv2.bn.weight matches model.model.4.m.3.cv2.bn.weight
# Layer 122: model.model.4.m.3.cv2.bn.bias matches model.model.4.m.3.cv2.bn.bias
# Layer 125: model.model.4.m.3.cv2.bn.num_batches_tracked matches model.model.4.m.3.cv2.bn.num_batches_tracked
# Layer 126: model.model.4.m.4.cv1.conv.weight matches model.model.4.m.4.cv1.conv.weight
# Layer 127: model.model.4.m.4.cv1.bn.weight matches model.model.4.m.4.cv1.bn.weight
# Layer 128: model.model.4.m.4.cv1.bn.bias matches model.model.4.m.4.cv1.bn.bias
# Layer 131: model.model.4.m.4.cv1.bn.num_batches_tracked matches model.model.4.m.4.cv1.bn.num_batches_tracked
# Layer 132: model.model.4.m.4.cv2.conv.weight matches model.model.4.m.4.cv2.conv.weight
# Layer 133: model.model.4.m.4.cv2.bn.weight matches model.model.4.m.4.cv2.bn.weight
# Layer 134: model.model.4.m.4.cv2.bn.bias matches model.model.4.m.4.cv2.bn.bias
# Layer 137: model.model.4.m.4.cv2.bn.num_batches_tracked matches model.model.4.m.4.cv2.bn.num_batches_tracked
# Layer 138: model.model.4.m.5.cv1.conv.weight matches model.model.4.m.5.cv1.conv.weight
# Layer 139: model.model.4.m.5.cv1.bn.weight matches model.model.4.m.5.cv1.bn.weight
# Layer 140: model.model.4.m.5.cv1.bn.bias matches model.model.4.m.5.cv1.bn.bias
# Layer 143: model.model.4.m.5.cv1.bn.num_batches_tracked matches model.model.4.m.5.cv1.bn.num_batches_tracked
# Layer 144: model.model.4.m.5.cv2.conv.weight matches model.model.4.m.5.cv2.conv.weight
# Layer 145: model.model.4.m.5.cv2.bn.weight matches model.model.4.m.5.cv2.bn.weight
# Layer 146: model.model.4.m.5.cv2.bn.bias matches model.model.4.m.5.cv2.bn.bias
# Layer 149: model.model.4.m.5.cv2.bn.num_batches_tracked matches model.model.4.m.5.cv2.bn.num_batches_tracked
# Layer 150: model.model.5.conv.weight matches model.model.5.conv.weight
# Layer 151: model.model.5.bn.weight matches model.model.5.bn.weight
# Layer 152: model.model.5.bn.bias matches model.model.5.bn.bias
# Layer 155: model.model.5.bn.num_batches_tracked matches model.model.5.bn.num_batches_tracked
# Layer 156: model.model.6.cv1.conv.weight matches model.model.6.cv1.conv.weight
# Layer 157: model.model.6.cv1.bn.weight matches model.model.6.cv1.bn.weight
# Layer 158: model.model.6.cv1.bn.bias matches model.model.6.cv1.bn.bias
# Layer 161: model.model.6.cv1.bn.num_batches_tracked matches model.model.6.cv1.bn.num_batches_tracked
# Layer 162: model.model.6.cv2.conv.weight matches model.model.6.cv2.conv.weight
# Layer 163: model.model.6.cv2.bn.weight matches model.model.6.cv2.bn.weight
# Layer 164: model.model.6.cv2.bn.bias matches model.model.6.cv2.bn.bias
# Layer 167: model.model.6.cv2.bn.num_batches_tracked matches model.model.6.cv2.bn.num_batches_tracked
# Layer 168: model.model.6.m.0.cv1.conv.weight matches model.model.6.m.0.cv1.conv.weight
# Layer 169: model.model.6.m.0.cv1.bn.weight matches model.model.6.m.0.cv1.bn.weight
# Layer 170: model.model.6.m.0.cv1.bn.bias matches model.model.6.m.0.cv1.bn.bias
# Layer 173: model.model.6.m.0.cv1.bn.num_batches_tracked matches model.model.6.m.0.cv1.bn.num_batches_tracked
# Layer 174: model.model.6.m.0.cv2.conv.weight matches model.model.6.m.0.cv2.conv.weight
# Layer 175: model.model.6.m.0.cv2.bn.weight matches model.model.6.m.0.cv2.bn.weight
# Layer 176: model.model.6.m.0.cv2.bn.bias matches model.model.6.m.0.cv2.bn.bias
# Layer 179: model.model.6.m.0.cv2.bn.num_batches_tracked matches model.model.6.m.0.cv2.bn.num_batches_tracked
# Layer 180: model.model.6.m.1.cv1.conv.weight matches model.model.6.m.1.cv1.conv.weight
# Layer 181: model.model.6.m.1.cv1.bn.weight matches model.model.6.m.1.cv1.bn.weight
# Layer 182: model.model.6.m.1.cv1.bn.bias matches model.model.6.m.1.cv1.bn.bias
# Layer 185: model.model.6.m.1.cv1.bn.num_batches_tracked matches model.model.6.m.1.cv1.bn.num_batches_tracked
# Layer 186: model.model.6.m.1.cv2.conv.weight matches model.model.6.m.1.cv2.conv.weight
# Layer 187: model.model.6.m.1.cv2.bn.weight matches model.model.6.m.1.cv2.bn.weight
# Layer 188: model.model.6.m.1.cv2.bn.bias matches model.model.6.m.1.cv2.bn.bias
# Layer 191: model.model.6.m.1.cv2.bn.num_batches_tracked matches model.model.6.m.1.cv2.bn.num_batches_tracked
# Layer 192: model.model.6.m.2.cv1.conv.weight matches model.model.6.m.2.cv1.conv.weight
# Layer 193: model.model.6.m.2.cv1.bn.weight matches model.model.6.m.2.cv1.bn.weight
# Layer 194: model.model.6.m.2.cv1.bn.bias matches model.model.6.m.2.cv1.bn.bias
# Layer 197: model.model.6.m.2.cv1.bn.num_batches_tracked matches model.model.6.m.2.cv1.bn.num_batches_tracked
# Layer 198: model.model.6.m.2.cv2.conv.weight matches model.model.6.m.2.cv2.conv.weight
# Layer 199: model.model.6.m.2.cv2.bn.weight matches model.model.6.m.2.cv2.bn.weight
# Layer 200: model.model.6.m.2.cv2.bn.bias matches model.model.6.m.2.cv2.bn.bias
# Layer 203: model.model.6.m.2.cv2.bn.num_batches_tracked matches model.model.6.m.2.cv2.bn.num_batches_tracked
# Layer 204: model.model.6.m.3.cv1.conv.weight matches model.model.6.m.3.cv1.conv.weight
# Layer 205: model.model.6.m.3.cv1.bn.weight matches model.model.6.m.3.cv1.bn.weight
# Layer 206: model.model.6.m.3.cv1.bn.bias matches model.model.6.m.3.cv1.bn.bias
# Layer 209: model.model.6.m.3.cv1.bn.num_batches_tracked matches model.model.6.m.3.cv1.bn.num_batches_tracked
# Layer 210: model.model.6.m.3.cv2.conv.weight matches model.model.6.m.3.cv2.conv.weight
# Layer 211: model.model.6.m.3.cv2.bn.weight matches model.model.6.m.3.cv2.bn.weight
# Layer 212: model.model.6.m.3.cv2.bn.bias matches model.model.6.m.3.cv2.bn.bias
# Layer 215: model.model.6.m.3.cv2.bn.num_batches_tracked matches model.model.6.m.3.cv2.bn.num_batches_tracked
# Layer 216: model.model.6.m.4.cv1.conv.weight matches model.model.6.m.4.cv1.conv.weight
# Layer 217: model.model.6.m.4.cv1.bn.weight matches model.model.6.m.4.cv1.bn.weight
# Layer 218: model.model.6.m.4.cv1.bn.bias matches model.model.6.m.4.cv1.bn.bias
# Layer 221: model.model.6.m.4.cv1.bn.num_batches_tracked matches model.model.6.m.4.cv1.bn.num_batches_tracked
# Layer 222: model.model.6.m.4.cv2.conv.weight matches model.model.6.m.4.cv2.conv.weight
# Layer 223: model.model.6.m.4.cv2.bn.weight matches model.model.6.m.4.cv2.bn.weight
# Layer 224: model.model.6.m.4.cv2.bn.bias matches model.model.6.m.4.cv2.bn.bias
# Layer 227: model.model.6.m.4.cv2.bn.num_batches_tracked matches model.model.6.m.4.cv2.bn.num_batches_tracked
# Layer 228: model.model.6.m.5.cv1.conv.weight matches model.model.6.m.5.cv1.conv.weight
# Layer 229: model.model.6.m.5.cv1.bn.weight matches model.model.6.m.5.cv1.bn.weight
# Layer 230: model.model.6.m.5.cv1.bn.bias matches model.model.6.m.5.cv1.bn.bias
# Layer 233: model.model.6.m.5.cv1.bn.num_batches_tracked matches model.model.6.m.5.cv1.bn.num_batches_tracked
# Layer 234: model.model.6.m.5.cv2.conv.weight matches model.model.6.m.5.cv2.conv.weight
# Layer 235: model.model.6.m.5.cv2.bn.weight matches model.model.6.m.5.cv2.bn.weight
# Layer 236: model.model.6.m.5.cv2.bn.bias matches model.model.6.m.5.cv2.bn.bias
# Layer 239: model.model.6.m.5.cv2.bn.num_batches_tracked matches model.model.6.m.5.cv2.bn.num_batches_tracked
# Layer 240: model.model.7.conv.weight matches model.model.7.conv.weight
# Layer 241: model.model.7.bn.weight matches model.model.7.bn.weight
# Layer 242: model.model.7.bn.bias matches model.model.7.bn.bias
# Layer 245: model.model.7.bn.num_batches_tracked matches model.model.7.bn.num_batches_tracked
# Layer 246: model.model.8.cv1.conv.weight matches model.model.8.cv1.conv.weight
# Layer 247: model.model.8.cv1.bn.weight matches model.model.8.cv1.bn.weight
# Layer 248: model.model.8.cv1.bn.bias matches model.model.8.cv1.bn.bias
# Layer 251: model.model.8.cv1.bn.num_batches_tracked matches model.model.8.cv1.bn.num_batches_tracked
# Layer 252: model.model.8.cv2.conv.weight matches model.model.8.cv2.conv.weight
# Layer 253: model.model.8.cv2.bn.weight matches model.model.8.cv2.bn.weight
# Layer 254: model.model.8.cv2.bn.bias matches model.model.8.cv2.bn.bias
# Layer 257: model.model.8.cv2.bn.num_batches_tracked matches model.model.8.cv2.bn.num_batches_tracked
# Layer 258: model.model.8.m.0.cv1.conv.weight matches model.model.8.m.0.cv1.conv.weight
# Layer 259: model.model.8.m.0.cv1.bn.weight matches model.model.8.m.0.cv1.bn.weight
# Layer 260: model.model.8.m.0.cv1.bn.bias matches model.model.8.m.0.cv1.bn.bias
# Layer 263: model.model.8.m.0.cv1.bn.num_batches_tracked matches model.model.8.m.0.cv1.bn.num_batches_tracked
# Layer 264: model.model.8.m.0.cv2.conv.weight matches model.model.8.m.0.cv2.conv.weight
# Layer 265: model.model.8.m.0.cv2.bn.weight matches model.model.8.m.0.cv2.bn.weight
# Layer 266: model.model.8.m.0.cv2.bn.bias matches model.model.8.m.0.cv2.bn.bias
# Layer 269: model.model.8.m.0.cv2.bn.num_batches_tracked matches model.model.8.m.0.cv2.bn.num_batches_tracked
# Layer 270: model.model.8.m.1.cv1.conv.weight matches model.model.8.m.1.cv1.conv.weight
# Layer 271: model.model.8.m.1.cv1.bn.weight matches model.model.8.m.1.cv1.bn.weight
# Layer 272: model.model.8.m.1.cv1.bn.bias matches model.model.8.m.1.cv1.bn.bias
# Layer 275: model.model.8.m.1.cv1.bn.num_batches_tracked matches model.model.8.m.1.cv1.bn.num_batches_tracked
# Layer 276: model.model.8.m.1.cv2.conv.weight matches model.model.8.m.1.cv2.conv.weight
# Layer 277: model.model.8.m.1.cv2.bn.weight matches model.model.8.m.1.cv2.bn.weight
# Layer 278: model.model.8.m.1.cv2.bn.bias matches model.model.8.m.1.cv2.bn.bias
# Layer 281: model.model.8.m.1.cv2.bn.num_batches_tracked matches model.model.8.m.1.cv2.bn.num_batches_tracked
# Layer 282: model.model.8.m.2.cv1.conv.weight matches model.model.8.m.2.cv1.conv.weight
# Layer 283: model.model.8.m.2.cv1.bn.weight matches model.model.8.m.2.cv1.bn.weight
# Layer 284: model.model.8.m.2.cv1.bn.bias matches model.model.8.m.2.cv1.bn.bias
# Layer 287: model.model.8.m.2.cv1.bn.num_batches_tracked matches model.model.8.m.2.cv1.bn.num_batches_tracked
# Layer 288: model.model.8.m.2.cv2.conv.weight matches model.model.8.m.2.cv2.conv.weight
# Layer 289: model.model.8.m.2.cv2.bn.weight matches model.model.8.m.2.cv2.bn.weight
# Layer 290: model.model.8.m.2.cv2.bn.bias matches model.model.8.m.2.cv2.bn.bias
# Layer 293: model.model.8.m.2.cv2.bn.num_batches_tracked matches model.model.8.m.2.cv2.bn.num_batches_tracked
# Layer 294: model.model.9.cv1.conv.weight matches model.model.9.cv1.conv.weight
# Layer 295: model.model.9.cv1.bn.weight matches model.model.9.cv1.bn.weight
# Layer 296: model.model.9.cv1.bn.bias matches model.model.9.cv1.bn.bias
# Layer 299: model.model.9.cv1.bn.num_batches_tracked matches model.model.9.cv1.bn.num_batches_tracked
# Layer 300: model.model.9.cv2.conv.weight matches model.model.9.cv2.conv.weight
# Layer 301: model.model.9.cv2.bn.weight matches model.model.9.cv2.bn.weight
# Layer 302: model.model.9.cv2.bn.bias matches model.model.9.cv2.bn.bias
# Layer 305: model.model.9.cv2.bn.num_batches_tracked matches model.model.9.cv2.bn.num_batches_tracked
# Layer 306: model.model.12.cv1.conv.weight matches model.model.12.cv1.conv.weight
# Layer 307: model.model.12.cv1.bn.weight matches model.model.12.cv1.bn.weight
# Layer 308: model.model.12.cv1.bn.bias matches model.model.12.cv1.bn.bias
# Layer 311: model.model.12.cv1.bn.num_batches_tracked matches model.model.12.cv1.bn.num_batches_tracked
# Layer 312: model.model.12.cv2.conv.weight matches model.model.12.cv2.conv.weight
# Layer 313: model.model.12.cv2.bn.weight matches model.model.12.cv2.bn.weight
# Layer 314: model.model.12.cv2.bn.bias matches model.model.12.cv2.bn.bias
# Layer 317: model.model.12.cv2.bn.num_batches_tracked matches model.model.12.cv2.bn.num_batches_tracked
# Layer 318: model.model.12.m.0.cv1.conv.weight matches model.model.12.m.0.cv1.conv.weight
# Layer 319: model.model.12.m.0.cv1.bn.weight matches model.model.12.m.0.cv1.bn.weight
# Layer 320: model.model.12.m.0.cv1.bn.bias matches model.model.12.m.0.cv1.bn.bias
# Layer 323: model.model.12.m.0.cv1.bn.num_batches_tracked matches model.model.12.m.0.cv1.bn.num_batches_tracked
# Layer 324: model.model.12.m.0.cv2.conv.weight matches model.model.12.m.0.cv2.conv.weight
# Layer 325: model.model.12.m.0.cv2.bn.weight matches model.model.12.m.0.cv2.bn.weight
# Layer 326: model.model.12.m.0.cv2.bn.bias matches model.model.12.m.0.cv2.bn.bias
# Layer 329: model.model.12.m.0.cv2.bn.num_batches_tracked matches model.model.12.m.0.cv2.bn.num_batches_tracked
# Layer 330: model.model.12.m.1.cv1.conv.weight matches model.model.12.m.1.cv1.conv.weight
# Layer 331: model.model.12.m.1.cv1.bn.weight matches model.model.12.m.1.cv1.bn.weight
# Layer 332: model.model.12.m.1.cv1.bn.bias matches model.model.12.m.1.cv1.bn.bias
# Layer 335: model.model.12.m.1.cv1.bn.num_batches_tracked matches model.model.12.m.1.cv1.bn.num_batches_tracked
# Layer 336: model.model.12.m.1.cv2.conv.weight matches model.model.12.m.1.cv2.conv.weight
# Layer 337: model.model.12.m.1.cv2.bn.weight matches model.model.12.m.1.cv2.bn.weight
# Layer 338: model.model.12.m.1.cv2.bn.bias matches model.model.12.m.1.cv2.bn.bias
# Layer 341: model.model.12.m.1.cv2.bn.num_batches_tracked matches model.model.12.m.1.cv2.bn.num_batches_tracked
# Layer 342: model.model.12.m.2.cv1.conv.weight matches model.model.12.m.2.cv1.conv.weight
# Layer 343: model.model.12.m.2.cv1.bn.weight matches model.model.12.m.2.cv1.bn.weight
# Layer 344: model.model.12.m.2.cv1.bn.bias matches model.model.12.m.2.cv1.bn.bias
# Layer 347: model.model.12.m.2.cv1.bn.num_batches_tracked matches model.model.12.m.2.cv1.bn.num_batches_tracked
# Layer 348: model.model.12.m.2.cv2.conv.weight matches model.model.12.m.2.cv2.conv.weight
# Layer 349: model.model.12.m.2.cv2.bn.weight matches model.model.12.m.2.cv2.bn.weight
# Layer 350: model.model.12.m.2.cv2.bn.bias matches model.model.12.m.2.cv2.bn.bias
# Layer 353: model.model.12.m.2.cv2.bn.num_batches_tracked matches model.model.12.m.2.cv2.bn.num_batches_tracked
# Layer 359: model.model.15.cv1.bn.num_batches_tracked matches model.model.15.cv1.bn.num_batches_tracked
# Layer 365: model.model.15.cv2.bn.num_batches_tracked matches model.model.15.cv2.bn.num_batches_tracked
# Layer 371: model.model.15.m.0.cv1.bn.num_batches_tracked matches model.model.15.m.0.cv1.bn.num_batches_tracked
# Layer 377: model.model.15.m.0.cv2.bn.num_batches_tracked matches model.model.15.m.0.cv2.bn.num_batches_tracked
# Layer 383: model.model.15.m.1.cv1.bn.num_batches_tracked matches model.model.15.m.1.cv1.bn.num_batches_tracked
# Layer 389: model.model.15.m.1.cv2.bn.num_batches_tracked matches model.model.15.m.1.cv2.bn.num_batches_tracked
# Layer 395: model.model.15.m.2.cv1.bn.num_batches_tracked matches model.model.15.m.2.cv1.bn.num_batches_tracked
# Layer 401: model.model.15.m.2.cv2.bn.num_batches_tracked matches model.model.15.m.2.cv2.bn.num_batches_tracked
# Layer 407: model.model.16.bn.num_batches_tracked matches model.model.16.bn.num_batches_tracked
# Layer 413: model.model.18.cv1.bn.num_batches_tracked matches model.model.18.cv1.bn.num_batches_tracked
# Layer 419: model.model.18.cv2.bn.num_batches_tracked matches model.model.18.cv2.bn.num_batches_tracked
# Layer 425: model.model.18.m.0.cv1.bn.num_batches_tracked matches model.model.18.m.0.cv1.bn.num_batches_tracked
# Layer 431: model.model.18.m.0.cv2.bn.num_batches_tracked matches model.model.18.m.0.cv2.bn.num_batches_tracked
# Layer 437: model.model.18.m.1.cv1.bn.num_batches_tracked matches model.model.18.m.1.cv1.bn.num_batches_tracked
# Layer 443: model.model.18.m.1.cv2.bn.num_batches_tracked matches model.model.18.m.1.cv2.bn.num_batches_tracked
# Layer 449: model.model.18.m.2.cv1.bn.num_batches_tracked matches model.model.18.m.2.cv1.bn.num_batches_tracked
# Layer 455: model.model.18.m.2.cv2.bn.num_batches_tracked matches model.model.18.m.2.cv2.bn.num_batches_tracked
# Layer 457: model.model.19.bn.weight matches model.model.19.bn.weight
# Layer 458: model.model.19.bn.bias matches model.model.19.bn.bias
# Layer 461: model.model.19.bn.num_batches_tracked matches model.model.19.bn.num_batches_tracked
# Layer 463: model.model.21.cv1.bn.weight matches model.model.21.cv1.bn.weight
# Layer 467: model.model.21.cv1.bn.num_batches_tracked matches model.model.21.cv1.bn.num_batches_tracked
# Layer 469: model.model.21.cv2.bn.weight matches model.model.21.cv2.bn.weight
# Layer 473: model.model.21.cv2.bn.num_batches_tracked matches model.model.21.cv2.bn.num_batches_tracked
# Layer 475: model.model.21.m.0.cv1.bn.weight matches model.model.21.m.0.cv1.bn.weight
# Layer 479: model.model.21.m.0.cv1.bn.num_batches_tracked matches model.model.21.m.0.cv1.bn.num_batches_tracked
# Layer 481: model.model.21.m.0.cv2.bn.weight matches model.model.21.m.0.cv2.bn.weight
# Layer 485: model.model.21.m.0.cv2.bn.num_batches_tracked matches model.model.21.m.0.cv2.bn.num_batches_tracked
# Layer 487: model.model.21.m.1.cv1.bn.weight matches model.model.21.m.1.cv1.bn.weight
# Layer 491: model.model.21.m.1.cv1.bn.num_batches_tracked matches model.model.21.m.1.cv1.bn.num_batches_tracked
# Layer 493: model.model.21.m.1.cv2.bn.weight matches model.model.21.m.1.cv2.bn.weight
# Layer 497: model.model.21.m.1.cv2.bn.num_batches_tracked matches model.model.21.m.1.cv2.bn.num_batches_tracked
# Layer 499: model.model.21.m.2.cv1.bn.weight matches model.model.21.m.2.cv1.bn.weight
# Layer 503: model.model.21.m.2.cv1.bn.num_batches_tracked matches model.model.21.m.2.cv1.bn.num_batches_tracked
# Layer 505: model.model.21.m.2.cv2.bn.weight matches model.model.21.m.2.cv2.bn.weight
# Layer 509: model.model.21.m.2.cv2.bn.num_batches_tracked matches model.model.21.m.2.cv2.bn.num_batches_tracked
# Layer 515: model.model.24.cv1.bn.num_batches_tracked matches model.model.22.cv2.0.0.bn.num_batches_tracked
# Layer 521: model.model.24.cv2.bn.num_batches_tracked matches model.model.22.cv2.0.1.bn.num_batches_tracked
# Layer 557: model.model.24.m.2.cv2.bn.num_batches_tracked matches model.model.22.cv3.0.0.bn.num_batches_tracked
# Layer 563: model.model.25.bn.num_batches_tracked matches model.model.22.cv3.0.1.bn.num_batches_tracked
#
# Non-matching Layers: 560
# Layer 3: model.model.0.bn.running_mean does not match model.model.0.bn.running_mean
# Layer 4: model.model.0.bn.running_var does not match model.model.0.bn.running_var
# Layer 9: model.model.1.bn.running_mean does not match model.model.1.bn.running_mean
# Layer 10: model.model.1.bn.running_var does not match model.model.1.bn.running_var
# Layer 15: model.model.2.cv1.bn.running_mean does not match model.model.2.cv1.bn.running_mean
# Layer 16: model.model.2.cv1.bn.running_var does not match model.model.2.cv1.bn.running_var
# Layer 21: model.model.2.cv2.bn.running_mean does not match model.model.2.cv2.bn.running_mean
# Layer 22: model.model.2.cv2.bn.running_var does not match model.model.2.cv2.bn.running_var
# Layer 27: model.model.2.m.0.cv1.bn.running_mean does not match model.model.2.m.0.cv1.bn.running_mean
# Layer 28: model.model.2.m.0.cv1.bn.running_var does not match model.model.2.m.0.cv1.bn.running_var
# Layer 33: model.model.2.m.0.cv2.bn.running_mean does not match model.model.2.m.0.cv2.bn.running_mean
# Layer 34: model.model.2.m.0.cv2.bn.running_var does not match model.model.2.m.0.cv2.bn.running_var
# Layer 39: model.model.2.m.1.cv1.bn.running_mean does not match model.model.2.m.1.cv1.bn.running_mean
# Layer 40: model.model.2.m.1.cv1.bn.running_var does not match model.model.2.m.1.cv1.bn.running_var
# Layer 45: model.model.2.m.1.cv2.bn.running_mean does not match model.model.2.m.1.cv2.bn.running_mean
# Layer 46: model.model.2.m.1.cv2.bn.running_var does not match model.model.2.m.1.cv2.bn.running_var
# Layer 51: model.model.2.m.2.cv1.bn.running_mean does not match model.model.2.m.2.cv1.bn.running_mean
# Layer 52: model.model.2.m.2.cv1.bn.running_var does not match model.model.2.m.2.cv1.bn.running_var
# Layer 57: model.model.2.m.2.cv2.bn.running_mean does not match model.model.2.m.2.cv2.bn.running_mean
# Layer 58: model.model.2.m.2.cv2.bn.running_var does not match model.model.2.m.2.cv2.bn.running_var
# Layer 63: model.model.3.bn.running_mean does not match model.model.3.bn.running_mean
# Layer 64: model.model.3.bn.running_var does not match model.model.3.bn.running_var
# Layer 69: model.model.4.cv1.bn.running_mean does not match model.model.4.cv1.bn.running_mean
# Layer 70: model.model.4.cv1.bn.running_var does not match model.model.4.cv1.bn.running_var
# Layer 75: model.model.4.cv2.bn.running_mean does not match model.model.4.cv2.bn.running_mean
# Layer 76: model.model.4.cv2.bn.running_var does not match model.model.4.cv2.bn.running_var
# Layer 81: model.model.4.m.0.cv1.bn.running_mean does not match model.model.4.m.0.cv1.bn.running_mean
# Layer 82: model.model.4.m.0.cv1.bn.running_var does not match model.model.4.m.0.cv1.bn.running_var
# Layer 87: model.model.4.m.0.cv2.bn.running_mean does not match model.model.4.m.0.cv2.bn.running_mean
# Layer 88: model.model.4.m.0.cv2.bn.running_var does not match model.model.4.m.0.cv2.bn.running_var
# Layer 93: model.model.4.m.1.cv1.bn.running_mean does not match model.model.4.m.1.cv1.bn.running_mean
# Layer 94: model.model.4.m.1.cv1.bn.running_var does not match model.model.4.m.1.cv1.bn.running_var
# Layer 99: model.model.4.m.1.cv2.bn.running_mean does not match model.model.4.m.1.cv2.bn.running_mean
# Layer 100: model.model.4.m.1.cv2.bn.running_var does not match model.model.4.m.1.cv2.bn.running_var
# Layer 105: model.model.4.m.2.cv1.bn.running_mean does not match model.model.4.m.2.cv1.bn.running_mean
# Layer 106: model.model.4.m.2.cv1.bn.running_var does not match model.model.4.m.2.cv1.bn.running_var
# Layer 111: model.model.4.m.2.cv2.bn.running_mean does not match model.model.4.m.2.cv2.bn.running_mean
# Layer 112: model.model.4.m.2.cv2.bn.running_var does not match model.model.4.m.2.cv2.bn.running_var
# Layer 117: model.model.4.m.3.cv1.bn.running_mean does not match model.model.4.m.3.cv1.bn.running_mean
# Layer 118: model.model.4.m.3.cv1.bn.running_var does not match model.model.4.m.3.cv1.bn.running_var
# Layer 123: model.model.4.m.3.cv2.bn.running_mean does not match model.model.4.m.3.cv2.bn.running_mean
# Layer 124: model.model.4.m.3.cv2.bn.running_var does not match model.model.4.m.3.cv2.bn.running_var
# Layer 129: model.model.4.m.4.cv1.bn.running_mean does not match model.model.4.m.4.cv1.bn.running_mean
# Layer 130: model.model.4.m.4.cv1.bn.running_var does not match model.model.4.m.4.cv1.bn.running_var
# Layer 135: model.model.4.m.4.cv2.bn.running_mean does not match model.model.4.m.4.cv2.bn.running_mean
# Layer 136: model.model.4.m.4.cv2.bn.running_var does not match model.model.4.m.4.cv2.bn.running_var
# Layer 141: model.model.4.m.5.cv1.bn.running_mean does not match model.model.4.m.5.cv1.bn.running_mean
# Layer 142: model.model.4.m.5.cv1.bn.running_var does not match model.model.4.m.5.cv1.bn.running_var
# Layer 147: model.model.4.m.5.cv2.bn.running_mean does not match model.model.4.m.5.cv2.bn.running_mean
# Layer 148: model.model.4.m.5.cv2.bn.running_var does not match model.model.4.m.5.cv2.bn.running_var
# Layer 153: model.model.5.bn.running_mean does not match model.model.5.bn.running_mean
# Layer 154: model.model.5.bn.running_var does not match model.model.5.bn.running_var
# Layer 159: model.model.6.cv1.bn.running_mean does not match model.model.6.cv1.bn.running_mean
# Layer 160: model.model.6.cv1.bn.running_var does not match model.model.6.cv1.bn.running_var
# Layer 165: model.model.6.cv2.bn.running_mean does not match model.model.6.cv2.bn.running_mean
# Layer 166: model.model.6.cv2.bn.running_var does not match model.model.6.cv2.bn.running_var
# Layer 171: model.model.6.m.0.cv1.bn.running_mean does not match model.model.6.m.0.cv1.bn.running_mean
# Layer 172: model.model.6.m.0.cv1.bn.running_var does not match model.model.6.m.0.cv1.bn.running_var
# Layer 177: model.model.6.m.0.cv2.bn.running_mean does not match model.model.6.m.0.cv2.bn.running_mean
# Layer 178: model.model.6.m.0.cv2.bn.running_var does not match model.model.6.m.0.cv2.bn.running_var
# Layer 183: model.model.6.m.1.cv1.bn.running_mean does not match model.model.6.m.1.cv1.bn.running_mean
# Layer 184: model.model.6.m.1.cv1.bn.running_var does not match model.model.6.m.1.cv1.bn.running_var
# Layer 189: model.model.6.m.1.cv2.bn.running_mean does not match model.model.6.m.1.cv2.bn.running_mean
# Layer 190: model.model.6.m.1.cv2.bn.running_var does not match model.model.6.m.1.cv2.bn.running_var
# Layer 195: model.model.6.m.2.cv1.bn.running_mean does not match model.model.6.m.2.cv1.bn.running_mean
# Layer 196: model.model.6.m.2.cv1.bn.running_var does not match model.model.6.m.2.cv1.bn.running_var
# Layer 201: model.model.6.m.2.cv2.bn.running_mean does not match model.model.6.m.2.cv2.bn.running_mean
# Layer 202: model.model.6.m.2.cv2.bn.running_var does not match model.model.6.m.2.cv2.bn.running_var
# Layer 207: model.model.6.m.3.cv1.bn.running_mean does not match model.model.6.m.3.cv1.bn.running_mean
# Layer 208: model.model.6.m.3.cv1.bn.running_var does not match model.model.6.m.3.cv1.bn.running_var
# Layer 213: model.model.6.m.3.cv2.bn.running_mean does not match model.model.6.m.3.cv2.bn.running_mean
# Layer 214: model.model.6.m.3.cv2.bn.running_var does not match model.model.6.m.3.cv2.bn.running_var
# Layer 219: model.model.6.m.4.cv1.bn.running_mean does not match model.model.6.m.4.cv1.bn.running_mean
# Layer 220: model.model.6.m.4.cv1.bn.running_var does not match model.model.6.m.4.cv1.bn.running_var
# Layer 225: model.model.6.m.4.cv2.bn.running_mean does not match model.model.6.m.4.cv2.bn.running_mean
# Layer 226: model.model.6.m.4.cv2.bn.running_var does not match model.model.6.m.4.cv2.bn.running_var
# Layer 231: model.model.6.m.5.cv1.bn.running_mean does not match model.model.6.m.5.cv1.bn.running_mean
# Layer 232: model.model.6.m.5.cv1.bn.running_var does not match model.model.6.m.5.cv1.bn.running_var
# Layer 237: model.model.6.m.5.cv2.bn.running_mean does not match model.model.6.m.5.cv2.bn.running_mean
# Layer 238: model.model.6.m.5.cv2.bn.running_var does not match model.model.6.m.5.cv2.bn.running_var
# Layer 243: model.model.7.bn.running_mean does not match model.model.7.bn.running_mean
# Layer 244: model.model.7.bn.running_var does not match model.model.7.bn.running_var
# Layer 249: model.model.8.cv1.bn.running_mean does not match model.model.8.cv1.bn.running_mean
# Layer 250: model.model.8.cv1.bn.running_var does not match model.model.8.cv1.bn.running_var
# Layer 255: model.model.8.cv2.bn.running_mean does not match model.model.8.cv2.bn.running_mean
# Layer 256: model.model.8.cv2.bn.running_var does not match model.model.8.cv2.bn.running_var
# Layer 261: model.model.8.m.0.cv1.bn.running_mean does not match model.model.8.m.0.cv1.bn.running_mean
# Layer 262: model.model.8.m.0.cv1.bn.running_var does not match model.model.8.m.0.cv1.bn.running_var
# Layer 267: model.model.8.m.0.cv2.bn.running_mean does not match model.model.8.m.0.cv2.bn.running_mean
# Layer 268: model.model.8.m.0.cv2.bn.running_var does not match model.model.8.m.0.cv2.bn.running_var
# Layer 273: model.model.8.m.1.cv1.bn.running_mean does not match model.model.8.m.1.cv1.bn.running_mean
# Layer 274: model.model.8.m.1.cv1.bn.running_var does not match model.model.8.m.1.cv1.bn.running_var
# Layer 279: model.model.8.m.1.cv2.bn.running_mean does not match model.model.8.m.1.cv2.bn.running_mean
# Layer 280: model.model.8.m.1.cv2.bn.running_var does not match model.model.8.m.1.cv2.bn.running_var
# Layer 285: model.model.8.m.2.cv1.bn.running_mean does not match model.model.8.m.2.cv1.bn.running_mean
# Layer 286: model.model.8.m.2.cv1.bn.running_var does not match model.model.8.m.2.cv1.bn.running_var
# Layer 291: model.model.8.m.2.cv2.bn.running_mean does not match model.model.8.m.2.cv2.bn.running_mean
# Layer 292: model.model.8.m.2.cv2.bn.running_var does not match model.model.8.m.2.cv2.bn.running_var
# Layer 297: model.model.9.cv1.bn.running_mean does not match model.model.9.cv1.bn.running_mean
# Layer 298: model.model.9.cv1.bn.running_var does not match model.model.9.cv1.bn.running_var
# Layer 303: model.model.9.cv2.bn.running_mean does not match model.model.9.cv2.bn.running_mean
# Layer 304: model.model.9.cv2.bn.running_var does not match model.model.9.cv2.bn.running_var
# Layer 309: model.model.12.cv1.bn.running_mean does not match model.model.12.cv1.bn.running_mean
# Layer 310: model.model.12.cv1.bn.running_var does not match model.model.12.cv1.bn.running_var
# Layer 315: model.model.12.cv2.bn.running_mean does not match model.model.12.cv2.bn.running_mean
# Layer 316: model.model.12.cv2.bn.running_var does not match model.model.12.cv2.bn.running_var
# Layer 321: model.model.12.m.0.cv1.bn.running_mean does not match model.model.12.m.0.cv1.bn.running_mean
# Layer 322: model.model.12.m.0.cv1.bn.running_var does not match model.model.12.m.0.cv1.bn.running_var
# Layer 327: model.model.12.m.0.cv2.bn.running_mean does not match model.model.12.m.0.cv2.bn.running_mean
# Layer 328: model.model.12.m.0.cv2.bn.running_var does not match model.model.12.m.0.cv2.bn.running_var
# Layer 333: model.model.12.m.1.cv1.bn.running_mean does not match model.model.12.m.1.cv1.bn.running_mean
# Layer 334: model.model.12.m.1.cv1.bn.running_var does not match model.model.12.m.1.cv1.bn.running_var
# Layer 339: model.model.12.m.1.cv2.bn.running_mean does not match model.model.12.m.1.cv2.bn.running_mean
# Layer 340: model.model.12.m.1.cv2.bn.running_var does not match model.model.12.m.1.cv2.bn.running_var
# Layer 345: model.model.12.m.2.cv1.bn.running_mean does not match model.model.12.m.2.cv1.bn.running_mean
# Layer 346: model.model.12.m.2.cv1.bn.running_var does not match model.model.12.m.2.cv1.bn.running_var
# Layer 351: model.model.12.m.2.cv2.bn.running_mean does not match model.model.12.m.2.cv2.bn.running_mean
# Layer 352: model.model.12.m.2.cv2.bn.running_var does not match model.model.12.m.2.cv2.bn.running_var
# Layer 354: model.model.15.cv1.conv.weight does not match model.model.15.cv1.conv.weight
# Layer 355: model.model.15.cv1.bn.weight does not match model.model.15.cv1.bn.weight
# Layer 356: model.model.15.cv1.bn.bias does not match model.model.15.cv1.bn.bias
# Layer 357: model.model.15.cv1.bn.running_mean does not match model.model.15.cv1.bn.running_mean
# Layer 358: model.model.15.cv1.bn.running_var does not match model.model.15.cv1.bn.running_var
# Layer 360: model.model.15.cv2.conv.weight does not match model.model.15.cv2.conv.weight
# Layer 361: model.model.15.cv2.bn.weight does not match model.model.15.cv2.bn.weight
# Layer 362: model.model.15.cv2.bn.bias does not match model.model.15.cv2.bn.bias
# Layer 363: model.model.15.cv2.bn.running_mean does not match model.model.15.cv2.bn.running_mean
# Layer 364: model.model.15.cv2.bn.running_var does not match model.model.15.cv2.bn.running_var
# Layer 366: model.model.15.m.0.cv1.conv.weight does not match model.model.15.m.0.cv1.conv.weight
# Layer 367: model.model.15.m.0.cv1.bn.weight does not match model.model.15.m.0.cv1.bn.weight
# Layer 368: model.model.15.m.0.cv1.bn.bias does not match model.model.15.m.0.cv1.bn.bias
# Layer 369: model.model.15.m.0.cv1.bn.running_mean does not match model.model.15.m.0.cv1.bn.running_mean
# Layer 370: model.model.15.m.0.cv1.bn.running_var does not match model.model.15.m.0.cv1.bn.running_var
# Layer 372: model.model.15.m.0.cv2.conv.weight does not match model.model.15.m.0.cv2.conv.weight
# Layer 373: model.model.15.m.0.cv2.bn.weight does not match model.model.15.m.0.cv2.bn.weight
# Layer 374: model.model.15.m.0.cv2.bn.bias does not match model.model.15.m.0.cv2.bn.bias
# Layer 375: model.model.15.m.0.cv2.bn.running_mean does not match model.model.15.m.0.cv2.bn.running_mean
# Layer 376: model.model.15.m.0.cv2.bn.running_var does not match model.model.15.m.0.cv2.bn.running_var
# Layer 378: model.model.15.m.1.cv1.conv.weight does not match model.model.15.m.1.cv1.conv.weight
# Layer 379: model.model.15.m.1.cv1.bn.weight does not match model.model.15.m.1.cv1.bn.weight
# Layer 380: model.model.15.m.1.cv1.bn.bias does not match model.model.15.m.1.cv1.bn.bias
# Layer 381: model.model.15.m.1.cv1.bn.running_mean does not match model.model.15.m.1.cv1.bn.running_mean
# Layer 382: model.model.15.m.1.cv1.bn.running_var does not match model.model.15.m.1.cv1.bn.running_var
# Layer 384: model.model.15.m.1.cv2.conv.weight does not match model.model.15.m.1.cv2.conv.weight
# Layer 385: model.model.15.m.1.cv2.bn.weight does not match model.model.15.m.1.cv2.bn.weight
# Layer 386: model.model.15.m.1.cv2.bn.bias does not match model.model.15.m.1.cv2.bn.bias
# Layer 387: model.model.15.m.1.cv2.bn.running_mean does not match model.model.15.m.1.cv2.bn.running_mean
# Layer 388: model.model.15.m.1.cv2.bn.running_var does not match model.model.15.m.1.cv2.bn.running_var
# Layer 390: model.model.15.m.2.cv1.conv.weight does not match model.model.15.m.2.cv1.conv.weight
# Layer 391: model.model.15.m.2.cv1.bn.weight does not match model.model.15.m.2.cv1.bn.weight
# Layer 392: model.model.15.m.2.cv1.bn.bias does not match model.model.15.m.2.cv1.bn.bias
# Layer 393: model.model.15.m.2.cv1.bn.running_mean does not match model.model.15.m.2.cv1.bn.running_mean
# Layer 394: model.model.15.m.2.cv1.bn.running_var does not match model.model.15.m.2.cv1.bn.running_var
# Layer 396: model.model.15.m.2.cv2.conv.weight does not match model.model.15.m.2.cv2.conv.weight
# Layer 397: model.model.15.m.2.cv2.bn.weight does not match model.model.15.m.2.cv2.bn.weight
# Layer 398: model.model.15.m.2.cv2.bn.bias does not match model.model.15.m.2.cv2.bn.bias
# Layer 399: model.model.15.m.2.cv2.bn.running_mean does not match model.model.15.m.2.cv2.bn.running_mean
# Layer 400: model.model.15.m.2.cv2.bn.running_var does not match model.model.15.m.2.cv2.bn.running_var
# Layer 402: model.model.16.conv.weight does not match model.model.16.conv.weight
# Layer 403: model.model.16.bn.weight does not match model.model.16.bn.weight
# Layer 404: model.model.16.bn.bias does not match model.model.16.bn.bias
# Layer 405: model.model.16.bn.running_mean does not match model.model.16.bn.running_mean
# Layer 406: model.model.16.bn.running_var does not match model.model.16.bn.running_var
# Layer 408: model.model.18.cv1.conv.weight does not match model.model.18.cv1.conv.weight
# Layer 409: model.model.18.cv1.bn.weight does not match model.model.18.cv1.bn.weight
# Layer 410: model.model.18.cv1.bn.bias does not match model.model.18.cv1.bn.bias
# Layer 411: model.model.18.cv1.bn.running_mean does not match model.model.18.cv1.bn.running_mean
# Layer 412: model.model.18.cv1.bn.running_var does not match model.model.18.cv1.bn.running_var
# Layer 414: model.model.18.cv2.conv.weight does not match model.model.18.cv2.conv.weight
# Layer 415: model.model.18.cv2.bn.weight does not match model.model.18.cv2.bn.weight
# Layer 416: model.model.18.cv2.bn.bias does not match model.model.18.cv2.bn.bias
# Layer 417: model.model.18.cv2.bn.running_mean does not match model.model.18.cv2.bn.running_mean
# Layer 418: model.model.18.cv2.bn.running_var does not match model.model.18.cv2.bn.running_var
# Layer 420: model.model.18.m.0.cv1.conv.weight does not match model.model.18.m.0.cv1.conv.weight
# Layer 421: model.model.18.m.0.cv1.bn.weight does not match model.model.18.m.0.cv1.bn.weight
# Layer 422: model.model.18.m.0.cv1.bn.bias does not match model.model.18.m.0.cv1.bn.bias
# Layer 423: model.model.18.m.0.cv1.bn.running_mean does not match model.model.18.m.0.cv1.bn.running_mean
# Layer 424: model.model.18.m.0.cv1.bn.running_var does not match model.model.18.m.0.cv1.bn.running_var
# Layer 426: model.model.18.m.0.cv2.conv.weight does not match model.model.18.m.0.cv2.conv.weight
# Layer 427: model.model.18.m.0.cv2.bn.weight does not match model.model.18.m.0.cv2.bn.weight
# Layer 428: model.model.18.m.0.cv2.bn.bias does not match model.model.18.m.0.cv2.bn.bias
# Layer 429: model.model.18.m.0.cv2.bn.running_mean does not match model.model.18.m.0.cv2.bn.running_mean
# Layer 430: model.model.18.m.0.cv2.bn.running_var does not match model.model.18.m.0.cv2.bn.running_var
# Layer 432: model.model.18.m.1.cv1.conv.weight does not match model.model.18.m.1.cv1.conv.weight
# Layer 433: model.model.18.m.1.cv1.bn.weight does not match model.model.18.m.1.cv1.bn.weight
# Layer 434: model.model.18.m.1.cv1.bn.bias does not match model.model.18.m.1.cv1.bn.bias
# Layer 435: model.model.18.m.1.cv1.bn.running_mean does not match model.model.18.m.1.cv1.bn.running_mean
# Layer 436: model.model.18.m.1.cv1.bn.running_var does not match model.model.18.m.1.cv1.bn.running_var
# Layer 438: model.model.18.m.1.cv2.conv.weight does not match model.model.18.m.1.cv2.conv.weight
# Layer 439: model.model.18.m.1.cv2.bn.weight does not match model.model.18.m.1.cv2.bn.weight
# Layer 440: model.model.18.m.1.cv2.bn.bias does not match model.model.18.m.1.cv2.bn.bias
# Layer 441: model.model.18.m.1.cv2.bn.running_mean does not match model.model.18.m.1.cv2.bn.running_mean
# Layer 442: model.model.18.m.1.cv2.bn.running_var does not match model.model.18.m.1.cv2.bn.running_var
# Layer 444: model.model.18.m.2.cv1.conv.weight does not match model.model.18.m.2.cv1.conv.weight
# Layer 445: model.model.18.m.2.cv1.bn.weight does not match model.model.18.m.2.cv1.bn.weight
# Layer 446: model.model.18.m.2.cv1.bn.bias does not match model.model.18.m.2.cv1.bn.bias
# Layer 447: model.model.18.m.2.cv1.bn.running_mean does not match model.model.18.m.2.cv1.bn.running_mean
# Layer 448: model.model.18.m.2.cv1.bn.running_var does not match model.model.18.m.2.cv1.bn.running_var
# Layer 450: model.model.18.m.2.cv2.conv.weight does not match model.model.18.m.2.cv2.conv.weight
# Layer 451: model.model.18.m.2.cv2.bn.weight does not match model.model.18.m.2.cv2.bn.weight
# Layer 452: model.model.18.m.2.cv2.bn.bias does not match model.model.18.m.2.cv2.bn.bias
# Layer 453: model.model.18.m.2.cv2.bn.running_mean does not match model.model.18.m.2.cv2.bn.running_mean
# Layer 454: model.model.18.m.2.cv2.bn.running_var does not match model.model.18.m.2.cv2.bn.running_var
# Layer 456: model.model.19.conv.weight does not match model.model.19.conv.weight
# Layer 459: model.model.19.bn.running_mean does not match model.model.19.bn.running_mean
# Layer 460: model.model.19.bn.running_var does not match model.model.19.bn.running_var
# Layer 462: model.model.21.cv1.conv.weight does not match model.model.21.cv1.conv.weight
# Layer 464: model.model.21.cv1.bn.bias does not match model.model.21.cv1.bn.bias
# Layer 465: model.model.21.cv1.bn.running_mean does not match model.model.21.cv1.bn.running_mean
# Layer 466: model.model.21.cv1.bn.running_var does not match model.model.21.cv1.bn.running_var
# Layer 468: model.model.21.cv2.conv.weight does not match model.model.21.cv2.conv.weight
# Layer 470: model.model.21.cv2.bn.bias does not match model.model.21.cv2.bn.bias
# Layer 471: model.model.21.cv2.bn.running_mean does not match model.model.21.cv2.bn.running_mean
# Layer 472: model.model.21.cv2.bn.running_var does not match model.model.21.cv2.bn.running_var
# Layer 474: model.model.21.m.0.cv1.conv.weight does not match model.model.21.m.0.cv1.conv.weight
# Layer 476: model.model.21.m.0.cv1.bn.bias does not match model.model.21.m.0.cv1.bn.bias
# Layer 477: model.model.21.m.0.cv1.bn.running_mean does not match model.model.21.m.0.cv1.bn.running_mean
# Layer 478: model.model.21.m.0.cv1.bn.running_var does not match model.model.21.m.0.cv1.bn.running_var
# Layer 480: model.model.21.m.0.cv2.conv.weight does not match model.model.21.m.0.cv2.conv.weight
# Layer 482: model.model.21.m.0.cv2.bn.bias does not match model.model.21.m.0.cv2.bn.bias
# Layer 483: model.model.21.m.0.cv2.bn.running_mean does not match model.model.21.m.0.cv2.bn.running_mean
# Layer 484: model.model.21.m.0.cv2.bn.running_var does not match model.model.21.m.0.cv2.bn.running_var
# Layer 486: model.model.21.m.1.cv1.conv.weight does not match model.model.21.m.1.cv1.conv.weight
# Layer 488: model.model.21.m.1.cv1.bn.bias does not match model.model.21.m.1.cv1.bn.bias
# Layer 489: model.model.21.m.1.cv1.bn.running_mean does not match model.model.21.m.1.cv1.bn.running_mean
# Layer 490: model.model.21.m.1.cv1.bn.running_var does not match model.model.21.m.1.cv1.bn.running_var
# Layer 492: model.model.21.m.1.cv2.conv.weight does not match model.model.21.m.1.cv2.conv.weight
# Layer 494: model.model.21.m.1.cv2.bn.bias does not match model.model.21.m.1.cv2.bn.bias
# Layer 495: model.model.21.m.1.cv2.bn.running_mean does not match model.model.21.m.1.cv2.bn.running_mean
# Layer 496: model.model.21.m.1.cv2.bn.running_var does not match model.model.21.m.1.cv2.bn.running_var
# Layer 498: model.model.21.m.2.cv1.conv.weight does not match model.model.21.m.2.cv1.conv.weight
# Layer 500: model.model.21.m.2.cv1.bn.bias does not match model.model.21.m.2.cv1.bn.bias
# Layer 501: model.model.21.m.2.cv1.bn.running_mean does not match model.model.21.m.2.cv1.bn.running_mean
# Layer 502: model.model.21.m.2.cv1.bn.running_var does not match model.model.21.m.2.cv1.bn.running_var
# Layer 504: model.model.21.m.2.cv2.conv.weight does not match model.model.21.m.2.cv2.conv.weight
# Layer 506: model.model.21.m.2.cv2.bn.bias does not match model.model.21.m.2.cv2.bn.bias
# Layer 507: model.model.21.m.2.cv2.bn.running_mean does not match model.model.21.m.2.cv2.bn.running_mean
# Layer 508: model.model.21.m.2.cv2.bn.running_var does not match model.model.21.m.2.cv2.bn.running_var
# Layer 510: model.model.24.cv1.conv.weight does not match model.model.22.cv2.0.0.conv.weight
# Layer 511: model.model.24.cv1.bn.weight does not match model.model.22.cv2.0.0.bn.weight
# Layer 512: model.model.24.cv1.bn.bias does not match model.model.22.cv2.0.0.bn.bias
# Layer 513: model.model.24.cv1.bn.running_mean does not match model.model.22.cv2.0.0.bn.running_mean
# Layer 514: model.model.24.cv1.bn.running_var does not match model.model.22.cv2.0.0.bn.running_var
# Layer 516: model.model.24.cv2.conv.weight does not match model.model.22.cv2.0.1.conv.weight
# Layer 517: model.model.24.cv2.bn.weight does not match model.model.22.cv2.0.1.bn.weight
# ...
# Layer 660: model.model.30.m.2.cv2.conv.weight does not match No matching layer in model_1
# Layer 661: model.model.30.m.2.cv2.bn.weight does not match No matching layer in model_1
# Layer 662: model.model.30.m.2.cv2.bn.bias does not match No matching layer in model_1
# Layer 663: model.model.30.m.2.cv2.bn.running_mean does not match No matching layer in model_1
# Layer 664: model.model.30.m.2.cv2.bn.running_var does not match No matching layer in model_1
# Layer 665: model.model.30.m.2.cv2.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 666: model.model.31.cv2.0.0.conv.weight does not match No matching layer in model_1
# Layer 667: model.model.31.cv2.0.0.bn.weight does not match No matching layer in model_1
# Layer 668: model.model.31.cv2.0.0.bn.bias does not match No matching layer in model_1
# Layer 669: model.model.31.cv2.0.0.bn.running_mean does not match No matching layer in model_1
# Layer 670: model.model.31.cv2.0.0.bn.running_var does not match No matching layer in model_1
# Layer 671: model.model.31.cv2.0.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 672: model.model.31.cv2.0.1.conv.weight does not match No matching layer in model_1
# Layer 673: model.model.31.cv2.0.1.bn.weight does not match No matching layer in model_1
# Layer 674: model.model.31.cv2.0.1.bn.bias does not match No matching layer in model_1
# Layer 675: model.model.31.cv2.0.1.bn.running_mean does not match No matching layer in model_1
# Layer 676: model.model.31.cv2.0.1.bn.running_var does not match No matching layer in model_1
# Layer 677: model.model.31.cv2.0.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 678: model.model.31.cv2.0.2.weight does not match No matching layer in model_1
# Layer 679: model.model.31.cv2.0.2.bias does not match No matching layer in model_1
# Layer 680: model.model.31.cv2.1.0.conv.weight does not match No matching layer in model_1
# Layer 681: model.model.31.cv2.1.0.bn.weight does not match No matching layer in model_1
# Layer 682: model.model.31.cv2.1.0.bn.bias does not match No matching layer in model_1
# Layer 683: model.model.31.cv2.1.0.bn.running_mean does not match No matching layer in model_1
# Layer 684: model.model.31.cv2.1.0.bn.running_var does not match No matching layer in model_1
# Layer 685: model.model.31.cv2.1.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 686: model.model.31.cv2.1.1.conv.weight does not match No matching layer in model_1
# Layer 687: model.model.31.cv2.1.1.bn.weight does not match No matching layer in model_1
# Layer 688: model.model.31.cv2.1.1.bn.bias does not match No matching layer in model_1
# Layer 689: model.model.31.cv2.1.1.bn.running_mean does not match No matching layer in model_1
# Layer 690: model.model.31.cv2.1.1.bn.running_var does not match No matching layer in model_1
# Layer 691: model.model.31.cv2.1.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 692: model.model.31.cv2.1.2.weight does not match No matching layer in model_1
# Layer 693: model.model.31.cv2.1.2.bias does not match No matching layer in model_1
# Layer 694: model.model.31.cv2.2.0.conv.weight does not match No matching layer in model_1
# Layer 695: model.model.31.cv2.2.0.bn.weight does not match No matching layer in model_1
# Layer 696: model.model.31.cv2.2.0.bn.bias does not match No matching layer in model_1
# Layer 697: model.model.31.cv2.2.0.bn.running_mean does not match No matching layer in model_1
# Layer 698: model.model.31.cv2.2.0.bn.running_var does not match No matching layer in model_1
# Layer 699: model.model.31.cv2.2.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 700: model.model.31.cv2.2.1.conv.weight does not match No matching layer in model_1
# Layer 701: model.model.31.cv2.2.1.bn.weight does not match No matching layer in model_1
# Layer 702: model.model.31.cv2.2.1.bn.bias does not match No matching layer in model_1
# Layer 703: model.model.31.cv2.2.1.bn.running_mean does not match No matching layer in model_1
# Layer 704: model.model.31.cv2.2.1.bn.running_var does not match No matching layer in model_1
# Layer 705: model.model.31.cv2.2.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 706: model.model.31.cv2.2.2.weight does not match No matching layer in model_1
# Layer 707: model.model.31.cv2.2.2.bias does not match No matching layer in model_1
# Layer 708: model.model.31.cv3.0.0.conv.weight does not match No matching layer in model_1
# Layer 709: model.model.31.cv3.0.0.bn.weight does not match No matching layer in model_1
# Layer 710: model.model.31.cv3.0.0.bn.bias does not match No matching layer in model_1
# Layer 711: model.model.31.cv3.0.0.bn.running_mean does not match No matching layer in model_1
# Layer 712: model.model.31.cv3.0.0.bn.running_var does not match No matching layer in model_1
# Layer 713: model.model.31.cv3.0.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 714: model.model.31.cv3.0.1.conv.weight does not match No matching layer in model_1
# Layer 715: model.model.31.cv3.0.1.bn.weight does not match No matching layer in model_1
# Layer 716: model.model.31.cv3.0.1.bn.bias does not match No matching layer in model_1
# Layer 717: model.model.31.cv3.0.1.bn.running_mean does not match No matching layer in model_1
# Layer 718: model.model.31.cv3.0.1.bn.running_var does not match No matching layer in model_1
# Layer 719: model.model.31.cv3.0.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 720: model.model.31.cv3.0.2.weight does not match No matching layer in model_1
# Layer 721: model.model.31.cv3.0.2.bias does not match No matching layer in model_1
# Layer 722: model.model.31.cv3.1.0.conv.weight does not match No matching layer in model_1
# Layer 723: model.model.31.cv3.1.0.bn.weight does not match No matching layer in model_1
# Layer 724: model.model.31.cv3.1.0.bn.bias does not match No matching layer in model_1
# Layer 725: model.model.31.cv3.1.0.bn.running_mean does not match No matching layer in model_1
# Layer 726: model.model.31.cv3.1.0.bn.running_var does not match No matching layer in model_1
# Layer 727: model.model.31.cv3.1.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 728: model.model.31.cv3.1.1.conv.weight does not match No matching layer in model_1
# Layer 729: model.model.31.cv3.1.1.bn.weight does not match No matching layer in model_1
# Layer 730: model.model.31.cv3.1.1.bn.bias does not match No matching layer in model_1
# Layer 731: model.model.31.cv3.1.1.bn.running_mean does not match No matching layer in model_1
# Layer 732: model.model.31.cv3.1.1.bn.running_var does not match No matching layer in model_1
# Layer 733: model.model.31.cv3.1.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 734: model.model.31.cv3.1.2.weight does not match No matching layer in model_1
# Layer 735: model.model.31.cv3.1.2.bias does not match No matching layer in model_1
# Layer 736: model.model.31.cv3.2.0.conv.weight does not match No matching layer in model_1
# Layer 737: model.model.31.cv3.2.0.bn.weight does not match No matching layer in model_1
# Layer 738: model.model.31.cv3.2.0.bn.bias does not match No matching layer in model_1
# Layer 739: model.model.31.cv3.2.0.bn.running_mean does not match No matching layer in model_1
# Layer 740: model.model.31.cv3.2.0.bn.running_var does not match No matching layer in model_1
# Layer 741: model.model.31.cv3.2.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 742: model.model.31.cv3.2.1.conv.weight does not match No matching layer in model_1
# Layer 743: model.model.31.cv3.2.1.bn.weight does not match No matching layer in model_1
# Layer 744: model.model.31.cv3.2.1.bn.bias does not match No matching layer in model_1
# Layer 745: model.model.31.cv3.2.1.bn.running_mean does not match No matching layer in model_1
# Layer 746: model.model.31.cv3.2.1.bn.running_var does not match No matching layer in model_1
# Layer 747: model.model.31.cv3.2.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 748: model.model.31.cv3.2.2.weight does not match No matching layer in model_1
# Layer 749: model.model.31.cv3.2.2.bias does not match No matching layer in model_1
# Layer 750: model.model.31.dfl.conv.weight does not match No matching layer in model_1
# Layer 751: model.model.32.cv2.0.0.conv.weight does not match No matching layer in model_1
# Layer 752: model.model.32.cv2.0.0.bn.weight does not match No matching layer in model_1
# Layer 753: model.model.32.cv2.0.0.bn.bias does not match No matching layer in model_1
# Layer 754: model.model.32.cv2.0.0.bn.running_mean does not match No matching layer in model_1
# Layer 755: model.model.32.cv2.0.0.bn.running_var does not match No matching layer in model_1
# Layer 756: model.model.32.cv2.0.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 757: model.model.32.cv2.0.1.conv.weight does not match No matching layer in model_1
# Layer 758: model.model.32.cv2.0.1.bn.weight does not match No matching layer in model_1
# Layer 759: model.model.32.cv2.0.1.bn.bias does not match No matching layer in model_1
# Layer 760: model.model.32.cv2.0.1.bn.running_mean does not match No matching layer in model_1
# Layer 761: model.model.32.cv2.0.1.bn.running_var does not match No matching layer in model_1
# Layer 762: model.model.32.cv2.0.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 763: model.model.32.cv2.0.2.weight does not match No matching layer in model_1
# Layer 764: model.model.32.cv2.0.2.bias does not match No matching layer in model_1
# Layer 765: model.model.32.cv2.1.0.conv.weight does not match No matching layer in model_1
# Layer 766: model.model.32.cv2.1.0.bn.weight does not match No matching layer in model_1
# Layer 767: model.model.32.cv2.1.0.bn.bias does not match No matching layer in model_1
# Layer 768: model.model.32.cv2.1.0.bn.running_mean does not match No matching layer in model_1
# Layer 769: model.model.32.cv2.1.0.bn.running_var does not match No matching layer in model_1
# Layer 770: model.model.32.cv2.1.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 771: model.model.32.cv2.1.1.conv.weight does not match No matching layer in model_1
# Layer 772: model.model.32.cv2.1.1.bn.weight does not match No matching layer in model_1
# Layer 773: model.model.32.cv2.1.1.bn.bias does not match No matching layer in model_1
# Layer 774: model.model.32.cv2.1.1.bn.running_mean does not match No matching layer in model_1
# Layer 775: model.model.32.cv2.1.1.bn.running_var does not match No matching layer in model_1
# Layer 776: model.model.32.cv2.1.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 777: model.model.32.cv2.1.2.weight does not match No matching layer in model_1
# Layer 778: model.model.32.cv2.1.2.bias does not match No matching layer in model_1
# Layer 779: model.model.32.cv2.2.0.conv.weight does not match No matching layer in model_1
# Layer 780: model.model.32.cv2.2.0.bn.weight does not match No matching layer in model_1
# Layer 781: model.model.32.cv2.2.0.bn.bias does not match No matching layer in model_1
# Layer 782: model.model.32.cv2.2.0.bn.running_mean does not match No matching layer in model_1
# Layer 783: model.model.32.cv2.2.0.bn.running_var does not match No matching layer in model_1
# Layer 784: model.model.32.cv2.2.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 785: model.model.32.cv2.2.1.conv.weight does not match No matching layer in model_1
# Layer 786: model.model.32.cv2.2.1.bn.weight does not match No matching layer in model_1
# Layer 787: model.model.32.cv2.2.1.bn.bias does not match No matching layer in model_1
# Layer 788: model.model.32.cv2.2.1.bn.running_mean does not match No matching layer in model_1
# Layer 789: model.model.32.cv2.2.1.bn.running_var does not match No matching layer in model_1
# Layer 790: model.model.32.cv2.2.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 791: model.model.32.cv2.2.2.weight does not match No matching layer in model_1
# Layer 792: model.model.32.cv2.2.2.bias does not match No matching layer in model_1
# Layer 793: model.model.32.cv3.0.0.conv.weight does not match No matching layer in model_1
# Layer 794: model.model.32.cv3.0.0.bn.weight does not match No matching layer in model_1
# Layer 795: model.model.32.cv3.0.0.bn.bias does not match No matching layer in model_1
# Layer 796: model.model.32.cv3.0.0.bn.running_mean does not match No matching layer in model_1
# Layer 797: model.model.32.cv3.0.0.bn.running_var does not match No matching layer in model_1
# Layer 798: model.model.32.cv3.0.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 799: model.model.32.cv3.0.1.conv.weight does not match No matching layer in model_1
# Layer 800: model.model.32.cv3.0.1.bn.weight does not match No matching layer in model_1
# Layer 801: model.model.32.cv3.0.1.bn.bias does not match No matching layer in model_1
# Layer 802: model.model.32.cv3.0.1.bn.running_mean does not match No matching layer in model_1
# Layer 803: model.model.32.cv3.0.1.bn.running_var does not match No matching layer in model_1
# Layer 804: model.model.32.cv3.0.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 805: model.model.32.cv3.0.2.weight does not match No matching layer in model_1
# Layer 806: model.model.32.cv3.0.2.bias does not match No matching layer in model_1
# Layer 807: model.model.32.cv3.1.0.conv.weight does not match No matching layer in model_1
# Layer 808: model.model.32.cv3.1.0.bn.weight does not match No matching layer in model_1
# Layer 809: model.model.32.cv3.1.0.bn.bias does not match No matching layer in model_1
# Layer 810: model.model.32.cv3.1.0.bn.running_mean does not match No matching layer in model_1
# Layer 811: model.model.32.cv3.1.0.bn.running_var does not match No matching layer in model_1
# Layer 812: model.model.32.cv3.1.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 813: model.model.32.cv3.1.1.conv.weight does not match No matching layer in model_1
# Layer 814: model.model.32.cv3.1.1.bn.weight does not match No matching layer in model_1
# Layer 815: model.model.32.cv3.1.1.bn.bias does not match No matching layer in model_1
# Layer 816: model.model.32.cv3.1.1.bn.running_mean does not match No matching layer in model_1
# Layer 817: model.model.32.cv3.1.1.bn.running_var does not match No matching layer in model_1
# Layer 818: model.model.32.cv3.1.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 819: model.model.32.cv3.1.2.weight does not match No matching layer in model_1
# Layer 820: model.model.32.cv3.1.2.bias does not match No matching layer in model_1
# Layer 821: model.model.32.cv3.2.0.conv.weight does not match No matching layer in model_1
# Layer 822: model.model.32.cv3.2.0.bn.weight does not match No matching layer in model_1
# Layer 823: model.model.32.cv3.2.0.bn.bias does not match No matching layer in model_1
# Layer 824: model.model.32.cv3.2.0.bn.running_mean does not match No matching layer in model_1
# Layer 825: model.model.32.cv3.2.0.bn.running_var does not match No matching layer in model_1
# Layer 826: model.model.32.cv3.2.0.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 827: model.model.32.cv3.2.1.conv.weight does not match No matching layer in model_1
# Layer 828: model.model.32.cv3.2.1.bn.weight does not match No matching layer in model_1
# Layer 829: model.model.32.cv3.2.1.bn.bias does not match No matching layer in model_1
# Layer 830: model.model.32.cv3.2.1.bn.running_mean does not match No matching layer in model_1
# Layer 831: model.model.32.cv3.2.1.bn.running_var does not match No matching layer in model_1
# Layer 832: model.model.32.cv3.2.1.bn.num_batches_tracked does not match No matching layer in model_1
# Layer 833: model.model.32.cv3.2.2.weight does not match No matching layer in model_1
# Layer 834: model.model.32.cv3.2.2.bias does not match No matching layer in model_1
# Layer 835: model.model.32.dfl.conv.weight does not match No matching layer in model_1

# %% [markdown]
# so I have a model named: model_yaml and a model name model_1 I want to compare the layers weights and not the layers names or keys, raw layer weights. If the weights are same return the layers number and key name and also return what layer and key numbers are not same. also model_yaml has more layers then model_1

# %%
#17 logo model head
model_1_output = model_1.predict("/home/areebadnan/Areeb_code/work/Atheritia/merged_images/pic13.jpg")[0]
# Out:
# image 1/1 /home/areebadnan/Areeb_code/work/Atheritia/merged_images/pic13.jpg: 544x640 (no detections), 16.4ms
# Speed: 1.1ms preprocess, 16.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)

# %%
#10 logo model head 
model_2_output = model_2.predict("/home/areebadnan/Areeb_code/work/Atheritia/merged_images/pic13.jpg")[0]
# Out:
# image 1/1 /home/areebadnan/Areeb_code/work/Atheritia/merged_images/pic13.jpg: 544x640 2 tipicos, 1 Volkswagen, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)

# %%
#17+10 logo model head 
merged_output = model_yaml.predict("/home/areebadnan/Areeb_code/work/Atheritia/merged_images/pic13.jpg")[0]
# Out:
# torch.Size([1, 21, 8400])
# torch.Size([1, 14, 8400])
# torch.Size([1, 21, 7140])
# torch.Size([1, 14, 7140])
# image 1/1 /home/areebadnan/Areeb_code/work/Atheritia/merged_images/pic13.jpg: 544x640 1 24, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)

# %%
# Validate with a custom dataset
metrics = model_yaml.val(data="/home/areebadnan/Areeb_code/work/Atheritia/Datasets/47_logos_dataset/10_classes_final/final/split2/data.yaml", project = '/home/areebadnan/Areeb_code/work/Atheritia/Datasets/47_logos_dataset/10_classes_final/final/split2/test/val_iterations', name = 'val6_1248_merged_model', imgsz=1248, conf=0.1)
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7721MiB)
# YOLOv8l-test summary (fused): 381 layers, 62,715,889 parameters, 45,777 gradients
# val: Scanning /home/areebadnan/Areeb_code/work/Atheritia/Datasets/47_logos_dataset/10_classes_final/final/split2/test/labels.cache... 5592 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5592/5592 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 350/350 [06:25<00:00,  1.10s/it]
#                    all       5592       9452      4e-05   7.43e-05   1.95e-05   3.89e-06
#                      0        612        940          0          0          0          0
#                      1        711        971          0          0          0          0
#                      2       1003       1189          0          0          0          0
#                      3        332        425          0          0          0          0
#                      4        424        934          0          0          0          0
#                      5        764       1346     0.0004   0.000743   0.000195   3.89e-05
#                      6       1100       1120          0          0          0          0
#                      7        743        974          0          0          0          0
#                      8        867        942          0          0          0          0
#                      9        141        611          0          0          0          0
# Speed: 0.5ms preprocess, 67.2ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/areebadnan/Areeb_code/work/Atheritia/Datasets/47_logos_dataset/10_classes_final/final/split2/test/val_iterations/val6_1248_merged_model2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def show_output(images):
    image = np.vstack(images)
    fig = plt.figure()
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    fig.set_size_inches((5,15))
    ax.imshow(image[...,::-1])

# %%
show_output([model_1_output.plot(), model_2_output.plot(), merged_output.plot()])
